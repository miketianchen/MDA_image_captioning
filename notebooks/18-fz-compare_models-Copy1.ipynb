# %%
import json
import sys
sys.path.append('../scr/evaluation/')
from eval_model import eval_model
from collections import defaultdict
import pandas as pd
import numpy as np

# %%
labels =\
['baseline (slow dataloader, glove embed)',
 'baseline (fast dataloader, glove embed)',
 'baseline (slow dataloader, glove embed, vgg16)',
 'baseline (fast dataloader, wiki2vec embed)',
 'attention v1 additive (fast dataloader, glove embed)',
 'attention v1 cosine similarity (fast dataloader, glove embed)',
 'attention v2 (fast dataloader, glove embed)',
 'attention v3 (fast dataloader, glove embed)',
 'multi attention (fast dataloader, wiki2vec embed)']

tags = ['9.1.1', '9.1.2', '9.1.3', '9.3', '11.1', '11.2', '15', '16', '19']
results_path = '../models'

# %%
# reference captions
ref_path = '../data/processed/json/'
with open(ref_path + 'valid.json', 'r') as jsonFile:
    ref = json.load(jsonFile)
    
# generated captions
results_path = '../models'
results = []
for tag in tags:
    with open(f'{results_path}/test_results_n{tag}.json', 'r') as f:
        results.append(json.load(f))

# %%
model_score_list = []
img_score_list = []
score_by_metrics_list = [] 
for i in range(len(results)):
    model_score, img_score, score_by_metrics = eval_model(ref, results[i])
    model_score_list.append(model_score)
    img_score_list.append(img_score)    
    score_by_metrics_list.append(score_by_metrics)
# Out:
# tokenization...
# computing Bleu score...
# computing METEOR score...
# computing Rouge score...
# computing CIDEr score...
# computing SPICE score...
# computing Universal_Sentence_Encoder_Similarity score...
# tokenization...
# computing Bleu score...
# computing METEOR score...
# computing Rouge score...
# computing CIDEr score...
# computing SPICE score...
# computing Universal_Sentence_Encoder_Similarity score...
# tokenization...
# computing Bleu score...
# computing METEOR score...
# computing Rouge score...
# computing CIDEr score...
# computing SPICE score...
# computing Universal_Sentence_Encoder_Similarity score...
# tokenization...
# computing Bleu score...
# computing METEOR score...
# computing Rouge score...
# computing CIDEr score...
# computing SPICE score...
# computing Universal_Sentence_Encoder_Similarity score...
# tokenization...
# computing Bleu score...
# computing METEOR score...
# computing Rouge score...
# computing CIDEr score...
# ...

# %%
model_scores = defaultdict(list)
for i in range(len(results)):
    for key, value in model_score_list[i].items():
        model_scores[key].append(value)

# %%
with open(f'../../s3/fz_notebooks/model_scores_n18.json', 'w') as fp:
    json.dump(model_scores, fp)

# %%
pd.DataFrame(model_scores, index=labels)
# Out:
#                                                       Bleu_1    Bleu_2  \
# baseline (slow dataloader, glove embed)             0.611067  0.482076
# baseline (fast dataloader, glove embed)             0.562602  0.427687
# baseline (slow dataloader, glove embed, vgg16)      0.651438  0.532721
# baseline (fast dataloader, wiki2vec embed)          0.533243  0.394759
# attention v1 additive (fast dataloader, glove e...  0.550454  0.417808
# attention v1 cosine similarity (fast dataloader...  0.528728  0.403139
# attention v2 (fast dataloader, glove embed)         0.539208  0.399820
# attention v3 (fast dataloader, glove embed)         0.560213  0.423594
# multi attention (fast dataloader, wiki2vec embed)   0.571188  0.439431
#
#                                                       Bleu_3    Bleu_4  \
# baseline (slow dataloader, glove embed)             0.400218  0.341686
# baseline (fast dataloader, glove embed)             0.346124  0.289424
# ...

# %% [markdown]
# ### Cross validation results

# %%
cv_results = []
for tag in tags:
    with open(f'{results_path}/cv_n{tag}.1.json', 'r') as f:
        cv_results.append(json.load(f))

# %%
cv_model_scores = defaultdict(list)
for i in range(len(cv_results)):
    for key, value in cv_results[i].items():
        cv_model_scores[key].append(np.mean(value))

# %%
pd.DataFrame(cv_model_scores, index=labels)
# Out:
#                                                       Bleu_1    Bleu_2  \
# baseline (slow dataloader, glove embed)             0.630387  0.502405
# baseline (fast dataloader, glove embed)             0.571112  0.436695
# baseline (slow dataloader, glove embed, vgg16)      0.646962  0.525585
# baseline (fast dataloader, wiki2vec embed)          0.562479  0.428895
# attention v1 additive (fast dataloader, glove e...  0.538477  0.403498
# attention v1 cosine similarity (fast dataloader...  0.553125  0.421104
# attention v2 (fast dataloader, glove embed)         0.539472  0.399479
# attention v3 (fast dataloader, glove embed)         0.561964  0.427331
# multi attention (fast dataloader, wiki2vec embed)   0.583291  0.451790
#
#                                                       Bleu_3    Bleu_4  \
# baseline (slow dataloader, glove embed)             0.419018  0.358968
# baseline (fast dataloader, glove embed)             0.353248  0.295929
# ...

# %% [markdown]
# ### Final models

# %%
final_results = []
for tag in tags:
    with open(f'{results_path}/final_results_n{tag}.2.json', 'r') as f:
        final_results.append(json.load(f))

# %%
test_model_scores = defaultdict(list)
for i in range(len(final_results)):
    for key, value in final_results[i]['test'].items():
        test_model_scores[key].append(value)

# %%
pd.DataFrame(test_model_scores, index=labels)
# Out:
#                                                       Bleu_1    Bleu_2  \
# baseline (slow dataloader, glove embed)             0.613683  0.485504
# baseline (fast dataloader, glove embed)             0.563380  0.426552
# baseline (slow dataloader, glove embed, vgg16)      0.647693  0.523183
# baseline (fast dataloader, wiki2vec embed)          0.569935  0.436095
# attention v1 additive (fast dataloader, glove e...  0.546758  0.408766
# attention v1 cosine similarity (fast dataloader...  0.553871  0.421735
# attention v2 (fast dataloader, glove embed)         0.528621  0.374602
# attention v3 (fast dataloader, glove embed)         0.572453  0.435279
# multi attention (fast dataloader, wiki2vec embed)   0.593290  0.462839
#
#                                                       Bleu_3    Bleu_4  \
# baseline (slow dataloader, glove embed)             0.402550  0.342993
# baseline (fast dataloader, glove embed)             0.343033  0.285420
# ...

# %%
sydney_model_scores = defaultdict(list)
for i in range(len(final_results)):
    for key, value in final_results[i]['sydney'].items():
        sydney_model_scores[key].append(value)

# %%
pd.DataFrame(sydney_model_scores, index=labels)
# Out:
#                                                       Bleu_1    Bleu_2  \
# baseline (slow dataloader, glove embed)             0.471430  0.236570
# baseline (fast dataloader, glove embed)             0.460740  0.221722
# baseline (slow dataloader, glove embed, vgg16)      0.452658  0.219591
# baseline (fast dataloader, wiki2vec embed)          0.463614  0.226409
# attention v1 additive (fast dataloader, glove e...  0.444297  0.209818
# attention v1 cosine similarity (fast dataloader...  0.451754  0.210224
# attention v2 (fast dataloader, glove embed)         0.460580  0.196258
# attention v3 (fast dataloader, glove embed)         0.431059  0.208996
# multi attention (fast dataloader, wiki2vec embed)   0.431402  0.193604
#
#                                                       Bleu_3    Bleu_4  \
# baseline (slow dataloader, glove embed)             0.124265  0.074495
# baseline (fast dataloader, glove embed)             0.109570  0.061574
# ...
