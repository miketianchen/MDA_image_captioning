# %%
import json
import numpy as np
import pandas as pd
from collections import defaultdict
from functools import reduce
from sklearn.model_selection import train_test_split

# %%
json_data = {}
sizes = {}
#set_name = ['rsicd', 'ucm', 'sydney']
set_name = ['rsicd', 'ucm']

# read in json files from all three datasets
for name in set_name:
    with open('../data/raw/dataset_' + name + '_modified.json', 'r') as data:
        json_data[name] = json.load(data)
        sizes[name] = len(json_data[name]['images'])
        print(f'There are {sizes[name]} images in the {name} dataset.')
# Out:
# There are 10921 images in the rsicd dataset.
# There are 2100 images in the ucm dataset.

# %%
ucm_data = {}
sydney_data = {}
rsicd_data = {}

for name in set_name:
    for single_image in json_data[name]['images']:
        new_filename = name + '_' + single_image['filename'][:-3] + 'jpg'
        if (name == 'rsicd'):
            rsicd_data[new_filename] = single_image
            rsicd_data[new_filename]['old_dataset_name'] = 'dataset_rsicd_modified'
        elif (name == 'ucm'):
            ucm_data[new_filename] = single_image
            ucm_data[new_filename]['old_dataset_name'] = 'dataset_ucm_modified'
        elif (name == 'sydney'):
            sydney_data[new_filename] = single_image
            sydney_data[new_filename]['old_dataset_name'] = 'dataset_sydney_modified'
        else: 
            print("uh-oh") #should add try catch later
            
print(f'There are {len(rsicd_data)} images in the rsicd dataset.')
print(f'There are {len(ucm_data)} images in the ucm dataset.')
print(f'There are {len(sydney_data)} images in the sydney dataset.')
# Out:
# There are 10921 images in the rsicd dataset.
# There are 2100 images in the ucm dataset.
# There are 0 images in the sydney dataset.

# %%
# Python code to merge dict 
def merge_2(dict1, dict2, dict3):
    dict2.update(dict1)
    return(dict3.update(dict2)) 

def merge(dict1, dict2, dict3): 
    res = {**dict1, **dict2, **dict3} 
    return res

# %%
combined_data = merge(rsicd_data, ucm_data, sydney_data)

# %%
len(combined_data)
# Out:
# 13021

# %%
combined_df = pd.DataFrame(combined_data).T

# %%
combined_df.head(-5)
# Out:
#                               filename imgid  \
# rsicd_airport_1.jpg      airport_1.jpg     0
# rsicd_airport_10.jpg    airport_10.jpg     1
# rsicd_airport_100.jpg  airport_100.jpg     2
# rsicd_airport_101.jpg  airport_101.jpg     3
# rsicd_airport_102.jpg  airport_102.jpg     4
# ...                                ...   ...
# ucm_2091.jpg                  2091.tif  2090
# ucm_2092.jpg                  2092.tif  2091
# ucm_2093.jpg                  2093.tif  2092
# ucm_2094.jpg                  2094.tif  2093
# ucm_2095.jpg                  2095.tif  2094
#
#                                                                sentences  \
# rsicd_airport_1.jpg    [{'tokens': ['many', 'planes', 'are', 'parked'...
# rsicd_airport_10.jpg   [{'tokens': ['some', 'planes', 'are', 'parked'...
# rsicd_airport_100.jpg  [{'tokens': ['many', 'planes', 'are', 'parked'...
# rsicd_airport_101.jpg  [{'tokens': ['many', 'planes', 'are', 'parked'...
# rsicd_airport_102.jpg  [{'tokens': ['several', 'buildings', 'and', 'g...
# ...                                                                  ...
# ucm_2091.jpg           [{'tokens': ['Two', 'tennis', 'courts', 'arran...
# ucm_2092.jpg           [{'tokens': ['Three', 'tennis', 'courts', 'arr...
# ucm_2093.jpg           [{'tokens': ['Three', 'tennis', 'courts', 'arr...
# ucm_2094.jpg           [{'tokens': ['Two', 'tennis', 'courts', 'on', ...
# ucm_2095.jpg           [{'tokens': ['A', 'small', 'tennis', 'court', ...
#
#                        split                              sentids  \
# rsicd_airport_1.jpg    train                      [0, 1, 2, 3, 4]
# rsicd_airport_10.jpg   train                      [5, 6, 7, 8, 9]
# rsicd_airport_100.jpg  train                 [10, 11, 12, 13, 14]
# rsicd_airport_101.jpg  train                 [15, 16, 17, 18, 19]
# rsicd_airport_102.jpg  train                 [20, 21, 22, 23, 24]
# ...                      ...                                  ...
# ucm_2091.jpg            test  [10450, 10451, 10452, 10453, 10454]
# ucm_2092.jpg            test  [10455, 10456, 10457, 10458, 10459]
# ucm_2093.jpg            test  [10460, 10461, 10462, 10463, 10464]
# ucm_2094.jpg            test  [10465, 10466, 10467, 10468, 10469]
# ucm_2095.jpg            test  [10470, 10471, 10472, 10473, 10474]
#
#                              old_dataset_name
# rsicd_airport_1.jpg    dataset_rsicd_modified
# rsicd_airport_10.jpg   dataset_rsicd_modified
# rsicd_airport_100.jpg  dataset_rsicd_modified
# rsicd_airport_101.jpg  dataset_rsicd_modified
# rsicd_airport_102.jpg  dataset_rsicd_modified
# ...                                       ...
# ucm_2091.jpg             dataset_ucm_modified
# ucm_2092.jpg             dataset_ucm_modified
# ucm_2093.jpg             dataset_ucm_modified
# ucm_2094.jpg             dataset_ucm_modified
# ucm_2095.jpg             dataset_ucm_modified
#
# [13016 rows x 6 columns]

# %%
train_valid, test = train_test_split(combined_df, test_size=0.2, random_state=123)
train, valid = train_test_split(train_valid, test_size=0.2, random_state=123)

# %%
len(train)
# Out:
# 8332

# %%
len(test)
# Out:
# 2605

# %%
len(valid)
# Out:
# 2084

# %%
train.head()
# Out:
#                                                 filename imgid  \
# ucm_1080.jpg                                    1080.tif  1079
# rsicd_denseresidential_363.jpg  denseresidential_363.jpg  2793
# rsicd_resort_126.jpg                      resort_126.jpg  7330
# rsicd_baseballfield_165.jpg        baseballfield_165.jpg   743
# ucm_18.jpg                                        18.tif    17
#
#                                                                         sentences  \
# ucm_1080.jpg                    [{'tokens': ['Lots', 'of', 'boats', 'docked', ...
# rsicd_denseresidential_363.jpg  [{'tokens': ['the', 'area', 'is', 'a', 'densel...
# rsicd_resort_126.jpg            [{'tokens': ['many', 'green', 'trees', 'and', ...
# rsicd_baseballfield_165.jpg     [{'tokens': ['the', 'fan', 'shaped', 'baseball...
# ucm_18.jpg                      [{'tokens': ['There', 'is', 'a', 'piece', 'of'...
#
#                                 split                              sentids  \
# ucm_1080.jpg                    train       [5395, 5396, 5397, 5398, 5399]
# rsicd_denseresidential_363.jpg  train  [13965, 13966, 13967, 13968, 13969]
# rsicd_resort_126.jpg            train  [36650, 36651, 36652, 36653, 36654]
# rsicd_baseballfield_165.jpg     train       [3715, 3716, 3717, 3718, 3719]
# ucm_18.jpg                      train                 [85, 86, 87, 88, 89]
#
#                                       old_dataset_name
# ucm_1080.jpg                      dataset_ucm_modified
# rsicd_denseresidential_363.jpg  dataset_rsicd_modified
# rsicd_resort_126.jpg            dataset_rsicd_modified
# rsicd_baseballfield_165.jpg     dataset_rsicd_modified
# ucm_18.jpg                        dataset_ucm_modified

# %%
test.head()
# Out:
#                             filename  imgid  \
# ucm_1096.jpg                1096.tif   1095
# rsicd_00188.jpg            00188.jpg  10187
# rsicd_meadow_209.jpg  meadow_209.jpg   4342
# rsicd_viaduct_37.jpg  viaduct_37.jpg   9880
# rsicd_00536.jpg            00536.jpg  10535
#
#                                                               sentences  \
# ucm_1096.jpg          [{'tokens': ['Lots', 'of', 'boats', 'docked', ...
# rsicd_00188.jpg       [{'tokens': ['the', 'bustling', 'block', 'embr...
# rsicd_meadow_209.jpg  [{'tokens': ['several', 'green', 'trees', 'are...
# rsicd_viaduct_37.jpg  [{'tokens': ['there', 'is', 'a', 'lake', 'near...
# rsicd_00536.jpg       [{'tokens': ['the', 'football', 'field', 'is',...
#
#                       split                              sentids  \
# ucm_1096.jpg           test       [5475, 5476, 5477, 5478, 5479]
# rsicd_00188.jpg       train  [50935, 50936, 50937, 50938, 50939]
# rsicd_meadow_209.jpg  train  [21710, 21711, 21712, 21713, 21714]
# rsicd_viaduct_37.jpg  train  [49400, 49401, 49402, 49403, 49404]
# rsicd_00536.jpg       train  [52675, 52676, 52677, 52678, 52679]
#
#                             old_dataset_name
# ucm_1096.jpg            dataset_ucm_modified
# rsicd_00188.jpg       dataset_rsicd_modified
# rsicd_meadow_209.jpg  dataset_rsicd_modified
# rsicd_viaduct_37.jpg  dataset_rsicd_modified
# rsicd_00536.jpg       dataset_rsicd_modified

# %%
valid.head()
# Out:
#                                                 filename imgid  \
# rsicd_park_3.jpg                              park_3.jpg  5352
# rsicd_mountain_176.jpg                  mountain_176.jpg  4875
# rsicd_denseresidential_210.jpg  denseresidential_210.jpg  2624
# rsicd_school_163.jpg                      school_163.jpg  8071
# ucm_997.jpg                                      997.tif   996
#
#                                                                         sentences  \
# rsicd_park_3.jpg                [{'tokens': ['the', 'lake', 'is', 'surrounded'...
# rsicd_mountain_176.jpg          [{'tokens': ['it', 'is', 'a', 'piece', 'of', '...
# rsicd_denseresidential_210.jpg  [{'tokens': ['the', 'residential', 'of', 'grey...
# rsicd_school_163.jpg            [{'tokens': ['the', 'road', 'through', 'the', ...
# ucm_997.jpg                     [{'tokens': ['This', 'is', 'a', 'part', 'of', ...
#
#                                 split                              sentids  \
# rsicd_park_3.jpg                train  [26760, 26761, 26762, 26763, 26764]
# rsicd_mountain_176.jpg          train  [24375, 24376, 24377, 24378, 24379]
# rsicd_denseresidential_210.jpg  train  [13120, 13121, 13122, 13123, 13124]
# rsicd_school_163.jpg            train  [40355, 40356, 40357, 40358, 40359]
# ucm_997.jpg                      test       [4980, 4981, 4982, 4983, 4984]
#
#                                       old_dataset_name
# rsicd_park_3.jpg                dataset_rsicd_modified
# rsicd_mountain_176.jpg          dataset_rsicd_modified
# rsicd_denseresidential_210.jpg  dataset_rsicd_modified
# rsicd_school_163.jpg            dataset_rsicd_modified
# ucm_997.jpg                       dataset_ucm_modified

# %%
train_dict = train.to_dict(orient='index')
test_dict = test.to_dict(orient='index')
valid_dict = valid.to_dict(orient='index')

# %%
# In each of the images add the current set name key-value pair
new_set_name = ['train', 'test', 'valid']
for name in new_set_name:
    if (name == 'train'):
        for key, value in train_dict.items():
            value['split'] = name
    elif (name == 'test'):
        for key, value in test_dict.items():
            value['split'] = name
    elif (name == 'valid'):
        for key, value in valid_dict.items():
            value['split'] = name
    else:
        print("uh-oh")

# %%
imgs_names = [(train_dict, 'train', train), 
              (valid_dict, 'valid', valid), 
              (test_dict, 'test', test)]

# %%
for imgs, name, _ in imgs_names:
    with open('../data/processed/json/' + name + '.json', 'w') as file:
        json.dump(imgs, file)

# %%
train_dict
# Out:
# {'ucm_1080.jpg': {'filename': '1080.tif',
#   'imgid': 1079,
#   'sentences': [{'tokens': ['Lots',
#      'of',
#      'boats',
#      'docked',
#      'at',
#      'the',
#      'harbor',
#      'and',
#      'the',
#      'boats',
#      'are',
#      'closed',
#      'to',
#      'each',
#      'other'],
#     'raw': 'Lots of boats docked at the harbor and the boats are closed to each other .',
#     'imgid': 1079,
#     'sentid': 5395},
#    {'tokens': ['Lots',
#      'of',
#      'boats',
#      'docked',
#      'neatly',
#      'at',
#      'the',
#      'harbor'],
#     'raw': 'Lots of boats docked neatly at the harbor .',
#     'imgid': 1079,
#     'sentid': 5396},
#    {'tokens': ['Many',
#      'boats',
#      'docked',
#      'neatly',
#      'at',
#      'the',
#      'harbor',
#      'and',
#      'the',
#      'water',
#      'is',
#      'deep',
#      'blue'],
#     'raw': 'Many boats docked neatly at the harbor and the water is deep blue .',
#     'imgid': 1079,
#     'sentid': 5397},
#    {'tokens': ['Many',
#      'boats',
#      'docked',
#      'neatly',
#      'at',
#      'the',
#      'harbor',
#      'and',
#      'some',
#      'positions',
#      'are',
#      'free'],
#     'raw': 'Many boats docked neatly at the harbor and some positions are free .',
#     'imgid': 1079,
#     'sentid': 5398},
#    {'tokens': ['Lots',
#      'of',
#      'boats',
#      'docked',
#      'neatly',
#      'at',
#      'the',
#      'harbor',
#      'and',
#      'the',
#      'boats',
#      'are',
#      'closed',
#      'to',
#      'each',
#      'other'],
#     'raw': 'Lots of boats docked neatly at the harbor and the boats are closed to each other .',
#     'imgid': 1079,
#     'sentid': 5399}],
#   'split': 'train',
#   'sentids': [5395, 5396, 5397, 5398, 5399],
#   'old_dataset_name': 'dataset_ucm_modified'},
#  'rsicd_denseresidential_363.jpg': {'filename': 'denseresidential_363.jpg',
#   'imgid': 2793,
#   'sentences': [{'tokens': ['the',
#      'area',
#      'is',
#      'a',
#      'densely',
#      'populated',
#      'area'],
#     'raw': 'the area is a densely populated area .',
#     'imgid': 2793,
#     'sentid': 13965},
#    {'tokens': ['many',
#      'green',
#      'plants',
#      'are',
#      'planted',
#      'around',
#      'the',
#      'neighborhood'],
#     'raw': 'many green plants are planted around the neighborhood .',
#     'imgid': 2793,
#     'sentid': 13966},
#    {'tokens': ['many',
#      'green',
#      'plants',
#      'are',
#      'planted',
#      'around',
#      'the',
#      'neighborhood'],
#     'raw': 'many green plants are planted around the neighborhood .',
#     'imgid': 2793,
#     'sentid': 13967},
#    {'tokens': ['the', 'area', 'is', 'a', 'densely', 'populated', 'area'],
#     'raw': 'the area is a densely populated area .',
#     'imgid': 2793,
#     'sentid': 13968},
#    {'tokens': ['the', 'area', 'is', 'a', 'densely', 'populated', 'area'],
#     'raw': 'the area is a densely populated area .',
#     'imgid': 2793,
#     'sentid': 13969}],
#   'split': 'train',
#   'sentids': [13965, 13966, 13967, 13968, 13969],
#   'old_dataset_name': 'dataset_rsicd_modified'},
#  'rsicd_resort_126.jpg': {'filename': 'resort_126.jpg',
#   'imgid': 7330,
#   'sentences': [{'tokens': ['many',
#      'green',
#      'trees',
#      'and',
#      'several',
#      'buildings',
#      'with',
#      'swimming',
#      'pools',
#      'are',
#      'near',
#      'a',
#      'beach',
#      'in',
#      'a',
#      'resort'],
#     'raw': 'many green trees and several buildings with swimming pools are near a beach in a resort .',
#     'imgid': 7330,
#     'sentid': 36650},
#    {'tokens': ['many',
#      'green',
#      'trees',
#      'and',
#      'several',
#      'buildings',
#      'with',
#      'swimming',
#      'pools',
#      'are',
#      'near',
#      'a',
#      'beach',
#      'in',
#      'a',
#      'resort'],
#     'raw': 'many green trees and several buildings with swimming pools are near a beach in a resort .',
#     'imgid': 7330,
#     'sentid': 36651},
#    {'tokens': ['many',
#      'green',
#      'trees',
#      'and',
#      'several',
#      'buildings',
#      'with',
#      'swimming',
#      'pools',
#      'are',
#      'near',
#      'a',
#      'beach',
#      'in',
#      'a',
#      'resort'],
#     'raw': 'many green trees and several buildings with swimming pools are near a beach in a resort .',
#     'imgid': 7330,
#     'sentid': 36652},
#    {'tokens': ['many',
#      'green',
#      'trees',
#      'and',
#      'several',
#      'buildings',
#      'with',
#      'swimming',
#      'pools',
#      'are',
#      'near',
#      'a',
#      'beach',
#      'in',
#      'a',
#      'resort'],
#     'raw': 'many green trees and several buildings with swimming pools are near a beach in a resort .',
#     'imgid': 7330,
#     'sentid': 36653},
#    {'tokens': ['many',
#      'green',
#      'trees',
#      'and',
#      'several',
#      'buildings',
#      'with',
#      'swimming',
#      'pools',
#      'are',
#      'near',
#      'a',
#      'beach',
#      'in',
#      'a',
#      'resort'],
#     'raw': 'many green trees and several buildings with swimming pools are near a beach in a resort .',
#     'imgid': 7330,
#     'sentid': 36654}],
#   'split': 'train',
#   'sentids': [36650, 36651, 36652, 36653, 36654],
#   'old_dataset_name': 'dataset_rsicd_modified'},
#  'rsicd_baseballfield_165.jpg': {'filename': 'baseballfield_165.jpg',
#   'imgid': 743,
#   'sentences': [{'tokens': ['the',
#      'fan',
#      'shaped',
#      'baseball',
#      'field',
#      'has',
#      'a',
#      'khaki',
#      'circular',
#      'infield'],
#     'raw': 'the fan shaped baseball field has a khaki circular infield .',
#     'imgid': 743,
#     'sentid': 3715},
#    {'tokens': ['there',
#      'is',
#      'a',
#      'lawn',
#      'with',
#      'a',
#      'baseball',
#      'field',
#      'built',
#      'on',
#      'it',
#      'on',
#      'both',
#      'side',
#      'of',
#      'which',
#      'are',
#      'parking',
#      'lot',
#      'with',
#      'cars'],
#     'raw': 'there is a lawn with a baseball field built on it on both side of which are parking lot with cars.',
#     'imgid': 743,
#     'sentid': 3716},
#    {'tokens': ['a',
#      'fanshaped',
#      'baseball',
#      'field',
#      'with',
#      'a',
#      'yellow',
#      'circle',
#      'sand'],
#     'raw': 'a fanshaped baseball field with a yellow circle sand .',
#     'imgid': 743,
#     'sentid': 3717},
#    {'tokens': ['several',
#      'trees',
#      'is',
#      'located',
#      'at',
#      'corners',
#      'of',
#      'the',
#      'baseball',
#      'field'],
#     'raw': 'several trees is located at corners of the baseball field',
#     'imgid': 743,
#     'sentid': 3718},
#    {'tokens': ['several',
#      'green',
#      'trees',
#      'and',
#      'several',
#      'cars',
#      'are',
#      'near',
#      'a',
#      'baseball',
#      'field'],
#     'raw': 'several green trees and several cars are near a baseball field .',
#     'imgid': 743,
#     'sentid': 3719}],
#   'split': 'train',
#   'sentids': [3715, 3716, 3717, 3718, 3719],
#   'old_dataset_name': 'dataset_rsicd_modified'},
#  'ucm_18.jpg': {'filename': '18.tif',
#   'imgid': 17,
#   'sentences': [{'tokens': ['There', 'is', 'a', 'piece', 'of', 'farmland'],
#     'raw': 'There is a piece of farmland .',
#     'imgid': 17,
#     'sentid': 85},
#    {'tokens': ['There', 'is', 'a', 'piece', 'of', 'cropland'],
#     'raw': 'There is a piece of cropland .',
#     'imgid': 17,
#     'sentid': 86},
#    {'tokens': ['It', 'is', 'a', 'piece', 'of', 'farmland'],
#     'raw': 'It is a piece of farmland .',
#     'imgid': 17,
#     'sentid': 87},
#    {'tokens': ['It', 'is', 'a', 'piece', 'of', 'cropland'],
#     'raw': 'It is a piece of cropland .',
#     'imgid': 17,
#     'sentid': 88},
#    {'tokens': ['Here', 'is', 'a', 'piece', 'of', 'farmland'],
#     'raw': 'Here is a piece of farmland .',
#     'imgid': 17,
#     'sentid': 89}],
#   'split': 'train',
#   'sentids': [85, 86, 87, 88, 89],
#   'old_dataset_name': 'dataset_ucm_modified'},
#  'rsicd_forest_163.jpg': {'filename': 'forest_163.jpg',
#   'imgid': 3651,
#   'sentences': [{'tokens': ['many',
#      'green',
#      'tree',
#      'form',
#      'a',
#      'piece',
#      'of',
#      'forest'],
#     'raw': 'many green tree form a piece of forest .',
#     'imgid': 3651,
#     'sentid': 18255},
#    {'tokens': ['many', 'green', 'tree', 'form', 'a', 'piece', 'of', 'forest'],
#     'raw': 'many green tree form a piece of forest .',
#     'imgid': 3651,
#     'sentid': 18256},
#    {'tokens': ['many', 'green', 'tree', 'form', 'a', 'piece', 'of', 'forest'],
#     'raw': 'many green tree form a piece of forest .',
#     'imgid': 3651,
#     'sentid': 18257},
#    {'tokens': ['many', 'green', 'tree', 'form', 'a', 'piece', 'of', 'forest'],
#     'raw': 'many green tree form a piece of forest .',
#     'imgid': 3651,
#     'sentid': 18258},
#    {'tokens': ['many', 'green', 'tree', 'form', 'a', 'piece', 'of', 'forest'],
#     'raw': 'many green tree form a piece of forest .',
#     'imgid': 3651,
#     'sentid': 18259}],
#   'split': 'train',
#   'sentids': [18255, 18256, 18257, 18258, 18259],
#   'old_dataset_name': 'dataset_rsicd_modified'},
#  'rsicd_square_323.jpg': {'filename': 'square_323.jpg',
#   'imgid': 8849,
#   'sentences': [{'tokens': ['many',
#      'trees',
#      'are',
#      'planted',
#      'around',
#      'the',
#      'brown',
#      'houses'],
#     'raw': 'many trees are planted around the brown houses .',
#     'imgid': 8849,
#     'sentid': 44245},
#    {'tokens': ['there',
#      'was',
#      'a',
#      'white',
#      'boat',
#      'in',
#      'front',
#      'of',
#      'a',
#      'white',
#      'roof'],
#     'raw': 'there was a white boat in front of a white roof .',
#     'imgid': 8849,
#     'sentid': 44246},
#    {'tokens': ['staggered',
#      'road',
#      'and',
#      'symmetrical',
#      'distribution',
#      'of',
#      'architectural',
#      'space'],
#     'raw': 'staggered road and symmetrical distribution of architectural space .',
#     'imgid': 8849,
#     'sentid': 44247},
#    {'tokens': ['this',
#      'is',
#      'a',
#      'uniform',
#      'moderate',
#      'vegetation',
#      '',
#      'the',
#      'construction',
#      'of',
#      'the',
#      'symmetric',
#      'distribution',
#      'of',
#      'the',
#      'space',
#      'map'],
#     'raw': 'this is a uniform, moderate vegetation, the construction of the symmetric distribution of the space map .',
#     'imgid': 8849,
#     'sentid': 44248},
#    {'tokens': ['staggered',
#      'road',
#      'and',
#      'symmetrical',
#      'distribution',
#      'of',
#      'architectural',
#      'space'],
#     'raw': 'staggered road and symmetrical distribution of architectural space .',
#     'imgid': 8849,
#     'sentid': 44249}],
#   'split': 'train',
#   'sentids': [44245, 44246, 44247, 44248, 44249],
#   'old_dataset_name': 'dataset_rsicd_modified'},
#  'rsicd_storagetanks_14.jpg': {'filename': 'storagetanks_14.jpg',
#   'imgid': 9265,
#   'sentences': [{'tokens': ['some',
#      'storage',
#      'tanks',
#      'are',
#      'surrounded',
#      'by',
#      'yellow',
#      'bare',
#      'land'],
#     'raw': 'some storage tanks are surrounded by yellow bare land.',
#     'imgid': 9265,
#     'sentid': 46325},
#    {'tokens': ['some',
#      'storage',
#      'tanks',
#      'are',
#      'surrounded',
#      'by',
#      'yellow',
#      'bare',
#      'land'],
#     'raw': 'some storage tanks are surrounded by yellow bare land.',
#     'imgid': 9265,
#     'sentid': 46326},
#    {'tokens': ['some',
#      'storage',
#      'tanks',
#      'are',
#      'surrounded',
#      'by',
#      'yellow',
#      'bare',
#      'land'],
#     'raw': 'some storage tanks are surrounded by yellow bare land.',
#     'imgid': 9265,
#     'sentid': 46327},
#    {'tokens': ['some',
#      'storage',
#      'tanks',
#      'are',
#      'surrounded',
#      'by',
#      'yellow',
#      'bare',
#      'land'],
#     'raw': 'some storage tanks are surrounded by yellow bare land.',
#     'imgid': 9265,
#     'sentid': 46328},
#    {'tokens': ['some',
#      'storage',
#      'tanks',
#      'are',
#      'surrounded',
#      'by',
#      'yellow',
#      'bare',
#      'land'],
#     'raw': 'some storage tanks are surrounded by yellow bare land.',
#     'imgid': 9265,
#     'sentid': 46329}],
#   'split': 'train',
#   'sentids': [46325, 46326, 46327, 46328, 46329],
#   'old_dataset_name': 'dataset_rsicd_modified'},
#  'ucm_1773.jpg': {'filename': '1773.tif',
#   'imgid': 1772,
#   'sentences': [{'tokens': ['It',
#      'is',
#      'a',
#      'straight',
#      'runway',
#      'with',
#      'some',
#      'mark',
#      'lines',
#      'on',
#      'it'],
#     'raw': 'It is a straight runway with some mark lines on it .',
#     'imgid': 1772,
#     'sentid': 8860},
#    {'tokens': ['A',
#      'straight',
#      'runway',
#      'with',
#      'some',
#      'mark',
#      'lines',
#      'on',
#      'it'],
#     'raw': 'A straight runway with some mark lines on it .',
#     'imgid': 1772,
#     'sentid': 8861},
#    {'tokens': ['There',
#      'are',
#      'some',
#      'mark',
#      'lines',
#      'on',
#      'the',
#      'straight',
#      'runway'],
#     'raw': 'There are some mark lines on the straight runway .',
#     'imgid': 1772,
#     'sentid': 8862},
#    {'tokens': ['It',
#      'is',
#      'a',
#      'straight',
#      'runway',
#      'with',
#      'some',
#      'white',
#      'mark',
#      'lines',
#      'on',
#      'it'],
#     'raw': 'It is a straight runway with some white mark lines on it .',
#     'imgid': 1772,
#     'sentid': 8863},
#    {'tokens': ['A',
#      'straight',
#      'runway',
#      'with',
#      'some',
#      'white',
#      'mark',
#      'lines',
#      'on',
#      'it'],
#     'raw': 'A straight runway with some white mark lines on it .',
#     'imgid': 1772,
#     'sentid': 8864}],
#   'split': 'train',
#   'sentids': [8860, 8861, 8862, 8863, 8864],
#   'old_dataset_name': 'dataset_ucm_modified'},
#  'rsicd_parking_301.jpg': {'filename': 'parking_301.jpg',
#   'imgid': 5705,
#   'sentences': [{'tokens': ['many',
#      'cars',
#      'are',
#      'parked',
#      'in',
#      'a',
#      'parking',
#      'lot',
#      'surrounded',
#      'by',
#      'a',
#      'building',
#      'and',
#      'several',
#      'lines',
#      'of',
#      'green',
#      'trees'],
#     'raw': 'many cars are parked in a parking lot surrounded by a building and several lines of green trees .',
#     'imgid': 5705,
#     'sentid': 28525},
#    {'tokens': ['many',
#      'cars',
#      'are',
#      'parked',
#      'in',
#      'a',
#      'parking',
#      'lot',
#      'surrounded',
#      'by',
#      'a',
#      'building',
#      'and',
#      'several',
#      'lines',
#      'of',
#      'green',
#      'trees'],
#     'raw': 'many cars are parked in a parking lot surrounded by a building and several lines of green trees .',
#     'imgid': 5705,
#     'sentid': 28526},
#    {'tokens': ['many',
#      'cars',
#      'are',
#      'parked',
#      'in',
#      'a',
#      'parking',
#      'lot',
#      'surrounded',
#      'by',
#      'a',
#      'building',
#      'and',
#      'several',
#      'lines',
#      'of',
#      'green',
#      'trees'],
#     'raw': 'many cars are parked in a parking lot surrounded by a building and several lines of green trees .',
#     'imgid': 5705,
#     'sentid': 28527},
#    {'tokens': ['many',
#      'cars',
#      'are',
#      'parked',
#      'in',
#      'a',
#      'parking',
#      'lot',
#      'surrounded',
#      'by',
#      'a',
#      'building',
#      'and',
#      'several',
#      'lines',
#      'of',
#      'green',
#      'trees'],
#     'raw': 'many cars are parked in a parking lot surrounded by a building and several lines of green trees .',
#     'imgid': 5705,
#     'sentid': 28528},
#    {'tokens': ['many',
#      'cars',
#      'are',
#      'parked',
#      'in',
#      'a',
#      'parking',
#      'lot',
#      'surrounded',
#      'by',
#      'a',
#      'building',
#      'and',
#      'several',
#      'lines',
#      'of',
#      'green',
#      'trees'],
#     'raw': 'many cars are parked in a parking lot surrounded by a building and several lines of green trees .',
#     'imgid': 5705,
#     'sentid': 28529}],
#   'split': 'train',
#   'sentids': [28525, 28526, 28527, 28528, 28529],
#   'old_dataset_name': 'dataset_rsicd_modified'},
#  'rsicd_school_264.jpg': {'filename': 'school_264.jpg',
#   'imgid': 8183,
#   'sentences': [{'tokens': ['surrounded',
#      'by',
#      'dark',
#      'green',
#      'trees',
#      'is',
#      'a',
#      'tall',
#      'building'],
#     'raw': 'surrounded by dark green trees is a tall building .',
#     'imgid': 8183,
#     'sentid': 40915},
#    {'tokens': ['northwest',
#      'of',
#      'the',
#      'school',
#      'to',
#      'a',
#      'large',
#      'forest',
#      'the',
#      'south',
#      'has',
#      'several',
#      'wetlands',
#      'and',
#      'teaching',
#      'buildings'],
#     'raw': 'northwest of the school to a large forest, the south has several wetlands and teaching buildings .',
#     'imgid': 8183,
#     'sentid': 40916},
#    {'tokens': ['some',
#      'buildings',
#      'and',
#      'many',
#      'green',
#      'trees',
#      'are',
#      'in',
#      'a',
#      'school'],
#     'raw': 'some buildings and many green trees are in a school .',
#     'imgid': 8183,
#     'sentid': 40917},
#    {'tokens': ['some',
#      'buildings',
#      'and',
#      'many',
#      'green',
#      'trees',
#      'are',
#      'in',
#      'a',
#      'school'],
#     'raw': 'some buildings and many green trees are in a school .',
#     'imgid': 8183,
#     'sentid': 40918},
#    {'tokens': ['surrounded',
#      'by',
#      'dark',
#      'green',
#      'trees',
#      'is',
#      'a',
#      'tall',
#      'building'],
#     'raw': 'surrounded by dark green trees is a tall building .',
#     'imgid': 8183,
#     'sentid': 40919}],
#   'split': 'train',
#   'sentids': [40915, 40916, 40917, 40918, 40919],
#   'old_dataset_name': 'dataset_rsicd_modified'},
#  'ucm_1587.jpg': {'filename': '1587.tif',
#   'imgid': 1586,
#   'sentences': [{'tokens': ['Lots',
#      'of',
#      'cars',
#      'are',
#      'very',
#      'closed',
#      'to',
#      'each',
#      'other',
#      'in',
#      'the',
#      'parking',
#      'lot'],
#     'raw': 'Lots of cars are very closed to each other in the parking lot .',
#     'imgid': 1586,
#     'sentid': 7930},
#    {'tokens': ['Lots',
#      'of',
#      'cars',
#      'parked',
#      'in',
#      'lines',
#      'in',
#      'the',
#      'parking',
#      'lot'],
#     'raw': 'Lots of cars parked in lines in the parking lot .',
#     'imgid': 1586,
#     'sentid': 7931},
#    {'tokens': ['Many',
#      'cars',
#      'are',
#      'densely',
#      'arranged',
#      'in',
#      'the',
#      'parking',
#      'lot'],
#     'raw': 'Many cars are densely arranged in the parking lot .',
#     'imgid': 1586,
#     'sentid': 7932},
#    {'tokens': ['It',
#      'is',
#      'a',
#      'parking',
#      'lot',
#      'with',
#      'many',
#      'cars',
#      'densely',
#      'arranged'],
#     'raw': 'It is a parking lot with many cars densely arranged .',
#     'imgid': 1586,
#     'sentid': 7933},
#    {'tokens': ['Many',
#      'cars',
#      'densely',
#      'arranged',
#      'in',
#      'the',
#      'parking',
#      'lot'],
#     'raw': 'Many cars densely arranged in the parking lot .',
#     'imgid': 1586,
#     'sentid': 7934}],
#   'split': 'train',
#   'sentids': [7930, 7931, 7932, 7933, 7934],
#   'old_dataset_name': 'dataset_ucm_modified'},
#  'rsicd_bareland_87.jpg': {'filename': 'bareland_87.jpg',
#   'imgid': 656,
#   'sentences': [{'tokens': ['there',
#      'are',
#      'white',
#      'and',
#      'gray',
#      'land',
#      'cover',
#      'on',
#      'the',
#      'part',
#      'of',
#      'the',
#      'red',
#      'land',
#      'a',
#      'few',
#      'green',
#      '',
#      'pot-holed',
#      'ground'],
#     'raw': 'there are white and gray land cover on the part of the red land, a few green, pot-holed ground .',
#     'imgid': 656,
#     'sentid': 3280},
#    {'tokens': ['it',
#      'is',
#      'a',
#      'large',
#      'piece',
#      'of',
#      'yellow',
#      'bare',
#      'land'],
#     'raw': 'it is a large piece of yellow bare land.',
#     'imgid': 656,
#     'sentid': 3281},
#    {'tokens': ['it',
#      'is',
#      'a',
#      'large',
#      'piece',
#      'of',
#      'yellow',
#      'bare',
#      'land'],
#     'raw': 'it is a large piece of yellow bare land.',
#     'imgid': 656,
#     'sentid': 3282},
#    {'tokens': ['there',
#      'are',
#      'white',
#      'and',
#      'gray',
#      'land',
#      'cover',
#      'on',
#      'the',
#      'part',
#      'of',
#      'the',
#      'red',
#      'land',
#      'a',
#      'few',
#      'green',
#      '',
#      'pot-holed',
#      'ground'],
#     'raw': 'there are white and gray land cover on the part of the red land, a few green, pot-holed ground .',
#     'imgid': 656,
#     'sentid': 3283},
#    {'tokens': ['there',
#      'are',
#      'white',
#      'and',
#      'gray',
#      'land',
#      'cover',
#      'on',
#      'the',
#      'part',
#      'of',
#      'the',
#      'red',
#      'land',
#      'a',
#      'few',
#      'green',
#      '',
#      'pot-holed',
#      'ground'],
#     'raw': 'there are white and gray land cover on the part of the red land, a few green, pot-holed ground .',
#     'imgid': 656,
#     'sentid': 3284}],
#   'split': 'train',
#   'sentids': [3280, 3281, 3282, 3283, 3284],
#   'old_dataset_name': 'dataset_rsicd_modified'},
#  'rsicd_denseresidential_179.jpg': {'filename': 'denseresidential_179.jpg',
#   'imgid': 2588,
#   'sentences': [{'tokens': ['many',
#      'buildings',
#      'and',
#      'green',
#      'trees',
#      'are',
#      'in',
#      'a',
#      'dense',
#      'residential',
#      'area'],
#     'raw': 'many buildings and green trees are in a dense residential area .',
#     'imgid': 2588,
#     'sentid': 12940},
#    {'tokens': ['many',
#      'buildings',
#      'and',
#      'green',
#      'trees',
#      'are',
#      'in',
#      'a',
#      'dense',
#      'residential',
#      'area'],
#     'raw': 'many buildings and green trees are in a dense residential area .',
#     'imgid': 2588,
#     'sentid': 12941},
#    {'tokens': ['many',
#      'buildings',
#      'and',
#      'green',
#      'trees',
#      'are',
#      'in',
#      'a',
#      'dense',
#      'residential',
#      'area'],
#     'raw': 'many buildings and green trees are in a dense residential area .',
#     'imgid': 2588,
#     'sentid': 12942},
#    {'tokens': ['many',
#      'buildings',
#      'and',
#      'green',
#      'trees',
#      'are',
#      'in',
#      'a',
#      'dense',
#      'residential',
#      'area'],
#     'raw': 'many buildings and green trees are in a dense residential area .',
#     'imgid': 2588,
#     'sentid': 12943},
#    {'tokens': ['many',
#      'buildings',
#      'and',
#      'green',
#      'trees',
#      'are',
#      'in',
#      'a',
#      'dense',
#      'residential',
#      'area'],
#     'raw': 'many buildings and green trees are in a dense residential area .',
#     'imgid': 2588,
#     'sentid': 12944}],
#   'split': 'train',
#   'sentids': [12940, 12941, 12942, 12943, 12944],
#   'old_dataset_name': 'dataset_rsicd_modified'},
#  'rsicd_resort_136.jpg': {'filename': 'resort_136.jpg',
#   'imgid': 7341,
#   'sentences': [{'tokens': ['many',
#      'buildings',
#      'and',
#      'some',
#      'green',
#      'trees',
#      'are',
#      'in',
#      'a',
#      'peninsula'],
#     'raw': 'many buildings and some green trees are in a peninsula .',
#     'imgid': 7341,
#     'sentid': 36705},
#    {'tokens': ['many',
#      'buildings',
#      'and',
#      'some',
#      'green',
#      'trees',
#      'are',
#      'in',
#      'a',
#      'peninsula'],
#     'raw': 'many buildings and some green trees are in a peninsula .',
#     'imgid': 7341,
#     'sentid': 36706},
#    {'tokens': ['many',
#      'buildings',
#      'and',
#      'some',
#      'green',
#      'trees',
#      'are',
#      'in',
#      'a',
#      'peninsula'],
#     'raw': 'many buildings and some green trees are in a peninsula .',
#     'imgid': 7341,
#     'sentid': 36707},
#    {'tokens': ['many',
#      'buildings',
#      'and',
#      'some',
#      'green',
#      'trees',
#      'are',
#      'in',
#      'a',
#      'peninsula'],
#     'raw': 'many buildings and some green trees are in a peninsula .',
#     'imgid': 7341,
#     'sentid': 36708},
#    {'tokens': ['many',
#      'buildings',
#      'and',
#      'some',
#      'green',
#      'trees',
#      'are',
#      'in',
#      'a',
#      'peninsula'],
#     'raw': 'many buildings and some green trees are in a peninsula .',
#     'imgid': 7341,
#     'sentid': 36709}],
#   'split': 'train',
#   'sentids': [36705, 36706, 36707, 36708, 36709],
#   'old_dataset_name': 'dataset_rsicd_modified'},
#  'rsicd_pond_346.jpg': {'filename': 'pond_346.jpg',
#   'imgid': 6514,
#   'sentences': [{'tokens': ['many',
#      'small',
#      'black',
#      'fish',
#      'are',
#      'in',
#      'the',
#      'pond'],
#     'raw': 'many small black fish are in the pond .',
#     'imgid': 6514,
#     'sentid': 32570},
#    {'tokens': ['the',
#      'pond',
#      'is',
#      'surrounded',
#      'by',
#      'light',
#      'green',
#      'lawns',
#      'and',
#      'vegetation'],
#     'raw': 'the pond is surrounded by light green lawns and vegetation .',
#     'imgid': 6514,
#     'sentid': 32571},
#    {'tokens': ['many',
#      'green',
#      'trees',
#      'and',
#      'meadows',
#      'are',
#      'around',
#      'an',
#      'almost',
#      'circle',
#      'green',
#      'pond'],
#     'raw': 'many green trees and meadows are around an almost circle green pond .',
#     'imgid': 6514,
#     'sentid': 32572},
#    {'tokens': ['many',
#      'green',
#      'trees',
#      'and',
#      'meadows',
#      'are',
#      'around',
#      'an',
#      'almost',
#      'circle',
#      'green',
#      'pond'],
#     'raw': 'many green trees and meadows are around an almost circle green pond .',
#     'imgid': 6514,
#     'sentid': 32573},
#    {'tokens': ['many', 'small', 'black', 'fish', 'are', 'in', 'the', 'pond'],
#     'raw': 'many small black fish are in the pond .',
#     'imgid': 6514,
#     'sentid': 32574}],
#   'split': 'train',
#   'sentids': [32570, 32571, 32572, 32573, 32574],
#   'old_dataset_name': 'dataset_rsicd_modified'},
#  'rsicd_sparseresidential_228.jpg': {'filename': 'sparseresidential_228.jpg',
#   'imgid': 8443,
#   'sentences': [{'tokens': ['a',
#      'building',
#      'with',
#      'a',
#      'swimming',
#      'pool',
#      'is',
#      'surrounded',
#      'by',
#      'many',
#      'green',
#      'trees',
#      'and',
#      'meadows'],
#     'raw': 'a building with a swimming pool is surrounded by many green trees and meadows .',
#     'imgid': 8443,
#     'sentid': 42215},
#    {'tokens': ['a',
#      'building',
#      'with',
#      'a',
#      'swimming',
#      'pool',
#      'is',
#      'surrounded',
#      'by',
#      'many',
#      'green',
#      'trees',
#      'and',
#      'meadows'],
#     'raw': 'a building with a swimming pool is surrounded by many green trees and meadows .',
#     'imgid': 8443,
#     'sentid': 42216},
#    {'tokens': ['a',
#      'building',
#      'with',
#      'a',
#      'swimming',
#      'pool',
#      'is',
#      'surrounded',
#      'by',
#      'many',
#      'green',
#      'trees',
#      'and',
#      'meadows'],
#     'raw': 'a building with a swimming pool is surrounded by many green trees and meadows .',
#     'imgid': 8443,
#     'sentid': 42217},
#    {'tokens': ['a',
#      'building',
#      'with',
#      'a',
#      'swimming',
#      'pool',
#      'is',
#      'surrounded',
#      'by',
#      'many',
#      'green',
#      'trees',
#      'and',
#      'meadows'],
#     'raw': 'a building with a swimming pool is surrounded by many green trees and meadows .',
#     'imgid': 8443,
#     'sentid': 42218},
#    {'tokens': ['a',
#      'building',
#      'with',
#      'a',
#      'swimming',
#      'pool',
#      'is',
#      'surrounded',
#      'by',
#      'many',
#      'green',
#      'trees',
#      'and',
#      'meadows'],
#     'raw': 'a building with a swimming pool is surrounded by many green trees and meadows .',
#     'imgid': 8443,
#     'sentid': 42219}],
#   'split': 'train',
#   'sentids': [42215, 42216, 42217, 42218, 42219],
#   'old_dataset_name': 'dataset_rsicd_modified'},
#  'rsicd_meadow_118.jpg': {'filename': 'meadow_118.jpg',
#   'imgid': 4241,
#   'sentences': [{'tokens': ['this',
#      'is',
#      'a',
#      'large',
#      'piece',
#      'of',
#      'green',
#      'meadow'],
#     'raw': 'this is a large piece of green meadow .',
#     'imgid': 4241,
#     'sentid': 21205},
#    {'tokens': ['this', 'is', 'a', 'large', 'piece', 'of', 'green', 'meadow'],
#     'raw': 'this is a large piece of green meadow .',
#     'imgid': 4241,
#     'sentid': 21206},
#    {'tokens': ['this', 'is', 'a', 'large', 'piece', 'of', 'green', 'meadow'],
#     'raw': 'this is a large piece of green meadow .',
#     'imgid': 4241,
#     'sentid': 21207},
#    {'tokens': ['this', 'is', 'a', 'large', 'piece', 'of', 'green', 'meadow'],
#     'raw': 'this is a large piece of green meadow .',
#     'imgid': 4241,
#     'sentid': 21208},
#    {'tokens': ['this', 'is', 'a', 'large', 'piece', 'of', 'green', 'meadow'],
#     'raw': 'this is a large piece of green meadow .',
#     'imgid': 4241,
#     'sentid': 21209}],
#   'split': 'train',
#   'sentids': [21205, 21206, 21207, 21208, 21209],
#   'old_dataset_name': 'dataset_rsicd_modified'},
#  'rsicd_desert_275.jpg': {'filename': 'desert_275.jpg',
#   'imgid': 3105,
#   'sentences': [{'tokens': ['a',
#      'piece',
#      'of',
#      'sand',
#      'in',
#      'the',
#      'desert',
#      'is',
#      'like',
#      'fish',
#      'scale'],
#     'raw': 'a piece of sand in the desert is like fish scale .',
#     'imgid': 3105,
#     'sentid': 15525},
#    {'tokens': ['a',
#      'piece',
#      'of',
#      'desert',
#      'is',
#      'dusty',
#      'barren',
#      'and',
#      'desolate'],
#     'raw': 'a piece of desert is dusty ,barren and desolate .',
#     'imgid': 3105,
#     'sentid': 15526},
#    {'tokens': ['many',
#      'ripples',
#      'like',
#      'fish',
#      'scales',
#      'are',
#      'in',
#      'a',
#      'piece',
#      'of',
#      'gray',
#      'desert'],
#     'raw': 'many ripples like fish scales are in a piece of gray desert .',
#     'imgid': 3105,
#     'sentid': 15527},
#    {'tokens': ['many',
#      'ripples',
#      'like',
#      'fish',
#      'scales',
#      'are',
#      'in',
#      'a',
#      'piece',
#      'of',
#      'gray',
#      'desert'],
#     'raw': 'many ripples like fish scales are in a piece of gray desert .',
#     'imgid': 3105,
#     'sentid': 15528},
#    {'tokens': ['a',
#      'piece',
#      'of',
#      'sand',
#      'in',
#      'the',
#      'desert',
#      'is',
#      'like',
#      'fish',
#      'scale'],
#     'raw': 'a piece of sand in the desert is like fish scale .',
#     'imgid': 3105,
#     'sentid': 15529}],
#   'split': 'train',
#   'sentids': [15525, 15526, 15527, 15528, 15529],
#   'old_dataset_name': 'dataset_rsicd_modified'},
#  'rsicd_baseballfield_35.jpg': {'filename': 'baseballfield_35.jpg',
#   'imgid': 819,
#   'sentences': [{'tokens': ['two',
#      'baseball',
#      'fields',
#      'are',
#      'near',
#      'several',
#      'green',
#      'trees'],
#     'raw': 'two baseball fields are near several green trees .',
#     'imgid': 819,
#     'sentid': 4095},
#    {'tokens': ['two',
#      'baseball',
#      'fields',
#      'are',
#      'near',
#      'several',
#      'green',
#      'trees'],
#     'raw': 'two baseball fields are near several green trees .',
#     'imgid': 819,
#     'sentid': 4096},
#    {'tokens': ['two',
#      'baseball',
#      'fields',
#      'are',
#      'near',
#      'several',
#      'green',
#      'trees'],
#     'raw': 'two baseball fields are near several green trees .',
#     'imgid': 819,
#     'sentid': 4097},
#    {'tokens': ['two',
#      'baseball',
#      'fields',
#      'are',
#      'near',
#      'several',
#      'green',
#      'trees'],
#     'raw': 'two baseball fields are near several green trees .',
#     'imgid': 819,
#     'sentid': 4098},
#    {'tokens': ['two',
#      'baseball',
#      'fields',
#      'are',
#      'near',
#      'several',
#      'green',
#      'trees'],
#     'raw': 'two baseball fields are near several green trees .',
#     'imgid': 819,
#     'sentid': 4099}],
#   'split': 'train',
#   'sentids': [4095, 4096, 4097, 4098, 4099],
#   'old_dataset_name': 'dataset_rsicd_modified'},
#  'ucm_200.jpg': {'filename': '200.tif',
#   'imgid': 199,
#   'sentences': [{'tokens': ['There',
#      'is',
#      'a',
#      'white',
#      'airplane',
#      'in',
#      'the',
#      'airport'],
#     'raw': 'There is a white airplane in the airport .',
#     'imgid': 199,
#     'sentid': 995},
#    {'tokens': ['An',
#      'airplane',
#      'is',
#      'stopped',
#      'at',
#      'the',
#      'airport',
#      'with',
#      'some',
#      'luggage',
#      'cars',
#      'beside',
#      'it'],
#     'raw': 'An airplane is stopped at the airport with some luggage cars beside it .',
#     'imgid': 199,
#     'sentid': 996},
#    {'tokens': ['It',
#      'is',
#      'a',
#      'white',
#      'airplane',
#      'stopped',
#      'at',
#      'the',
#      'airport'],
#     'raw': 'It is a white airplane stopped at the airport .',
#     'imgid': 199,
#     'sentid': 997},
#    {'tokens': ['There',
#      'is',
#      'an',
#      'airplane',
#      'stopped',
#      'at',
#      'the',
#      'airport'],
#     'raw': 'There is an airplane stopped at the airport .',
#     'imgid': 199,
#     'sentid': 998},
#    {'tokens': ['An',
#      'white',
#      'airplane',
#      'is',
#      'stopped',
#      'at',
#      'the',
#      'airport',
#      'with',
#      'some',
#      'luggage',
#      'cars',
#      'surrounded',
#      'it'],
#     'raw': 'An white airplane is stopped at the airport with some luggage cars surrounded it .',
#     'imgid': 199,
#     'sentid': 999}],
#   'split': 'train',
#   'sentids': [995, 996, 997, 998, 999],
#   'old_dataset_name': 'dataset_ucm_modified'},
#  'rsicd_stadium_182.jpg': {'filename': 'stadium_182.jpg',
#   'imgid': 9022,
#   'sentences': [{'tokens': ['there',
#      'is',
#      'a',
#      'football',
#      'field',
#      'enclosed',
#      'by',
#      'bleachers',
#      'is',
#      'surrounded',
#      'by',
#      'rows',
#      'of',
#      'automobiles'],
#     'raw': 'there is a football field enclosed by bleachers is surrounded by rows of automobiles .',
#     'imgid': 9022,
#     'sentid': 45110},
#    {'tokens': ['there',
#      'is',
#      'a',
#      'football',
#      'field',
#      'enclosed',
#      'by',
#      'stands',
#      'is',
#      'surrounded',
#      'by',
#      'rows',
#      'of',
#      'automobiles'],
#     'raw': 'there is a football field enclosed by stands is surrounded by rows of automobiles .',
#     'imgid': 9022,
#     'sentid': 45111},
#    {'tokens': ['there',
#      'is',
#      'a',
#      'football',
#      'field',
#      'enclosed',
#      'by',
#      'stands',
#      'is',
#      'surrounded',
#      'by',
#      'rows',
#      'of',
#      'automobiles'],
#     'raw': 'there is a football field enclosed by stands is surrounded by rows of automobiles .',
#     'imgid': 9022,
#     'sentid': 45112},
#    {'tokens': ['it',
#      'is',
#      'a',
#      'soccer',
#      'field',
#      'where',
#      'guys',
#      'are',
#      'playing',
#      'soccer',
#      'surrounded',
#      'by',
#      'rows',
#      'of',
#      'cars'],
#     'raw': 'it is a soccer field where guys are playing soccer surrounded by rows of cars .',
#     'imgid': 9022,
#     'sentid': 45113},
#    {'tokens': ['several',
#      'buildings',
#      'and',
#      'a',
#      'parking',
#      'lot',
#      'are',
#      'near',
#      'a',
#      'stadium',
#      'with',
#      'a',
#      'football',
#      'field',
#      'in',
#      'it'],
#     'raw': 'several buildings and a parking lot are near a stadium with a football field in it .',
#     'imgid': 9022,
#     'sentid': 45114}],
#   'split': 'train',
#   'sentids': [45110, 45111, 45112, 45113, 45114],
#   'old_dataset_name': 'dataset_rsicd_modified'},
#  'rsicd_bridge_312.jpg': {'filename': 'bridge_312.jpg',
#   'imgid': 1527,
#   'sentences': [{'tokens': ['a',
#      'bridge',
#      'connects',
#      'the',
#      'two',
#      'sides',
#      'of',
#      'the',
#      'river'],
#     'raw': 'a bridge connects the two sides of the river .',
#     'imgid': 1527,
#     'sentid': 7635},
#    {'tokens': ['one',
#      'side',
#      'of',
#      'the',
#      'bridge',
#      'is',
#      'the',
#      'city',
#      'the',
#      'other',
#      'side',
#      'is',
#      'a',
#      'green',
#      'area'],
#     'raw': 'one side of the bridge is the city, the other side is a green area .',
#     'imgid': 1527,
#     'sentid': 7636},
#    {'tokens': ['a',
#      'long',
#      'bridge',
#      'is',
#      'over',
#      'a',
#      'dark',
#      'green',
#      'river',
#      'with',
#      'two',
#      'red',
#      'boats'],
#     'raw': 'a long bridge is over a dark green river with two red boats .',
#     'imgid': 1527,
#     'sentid': 7637},
#    {'tokens': ['a',
#      'long',
#      'bridge',
#      'is',
#      'over',
#      'a',
#      'dark',
#      'green',
#      'river',
#      'with',
#      'two',
#      'red',
#      'boats'],
#     'raw': 'a long bridge is over a dark green river with two red boats .',
#     'imgid': 1527,
#     'sentid': 7638},
#    {'tokens': ['a',
#      'bridge',
#      'connects',
#      'the',
#      'two',
#      'sides',
#      'of',
#      'the',
#      'river'],
#     'raw': 'a bridge connects the two sides of the river .',
#     'imgid': 1527,
#     'sentid': 7639}],
#   'split': 'train',
#   'sentids': [7635, 7636, 7637, 7638, 7639],
#   'old_dataset_name': 'dataset_rsicd_modified'},
#  'rsicd_center_192.jpg': {'filename': 'center_192.jpg',
#   'imgid': 1753,
#   'sentences': [{'tokens': ['a',
#      'round',
#      'building',
#      'and',
#      'some',
#      'square',
#      'buildings',
#      'are',
#      'sandwiched',
#      'between',
#      'two',
#      'roads'],
#     'raw': 'a round building and some square buildings are sandwiched between two roads .',
#     'imgid': 1753,
#     'sentid': 8765},
#    {'tokens': ['a',
#      'round',
#      'building',
#      'and',
#      'some',
#      'square',
#      'buildings',
#      'are',
#      'sandwiched',
#      'between',
#      'two',
#      'roads'],
#     'raw': 'a round building and some square buildings are sandwiched between two roads .',
#     'imgid': 1753,
#     'sentid': 8766},
#    {'tokens': ['the', 'petaling', 'center', 'is', 'between', 'two', 'blocks'],
#     'raw': 'the petaling center is between two blocks .',
#     'imgid': 1753,
#     'sentid': 8767},
#    {'tokens': ['here',
#      'we',
#      'can',
#      'see',
#      'a',
#      'aesthetic',
#      'round',
#      'center',
#      'surrounded',
#      'by',
#      'roads'],
#     'raw': 'here we can see a aesthetic round center surrounded by roads .',
#     'imgid': 1753,
#     'sentid': 8768},
#    {'tokens': ['a',
#      'circle',
#      'building',
#      'is',
#      'near',
#      'a',
#      'building',
#      'and',
#      'two',
#      'roads'],
#     'raw': 'a circle building is near a building and two roads .',
#     'imgid': 1753,
#     'sentid': 8769}],
#   'split': 'train',
#   'sentids': [8765, 8766, 8767, 8768, 8769],
#   'old_dataset_name': 'dataset_rsicd_modified'},
#  'rsicd_00214.jpg': {'filename': '00214.jpg',
#   'imgid': 10213,
#   'sentences': [{'tokens': ['this',
#      'area',
#      'is',
#      'still',
#      'under',
#      'construction',
#      'while',
#      'its',
#      'parking',
#      'lot',
#      'and',
#      'a',
#      'lot',
#      'of',
#      'courts',
#      'have',
#      'been',
#      'built'],
#     'raw': 'this area is still under construction while its parking lot and a lot of courts have been built .',
#     'imgid': 10213,
#     'sentid': 51065},
#    {'tokens': ['nine',
#      'small',
#      'basketball',
#      'fields',
#      'locate',
#      'in',
#      'an',
#      'irregular',
#      'area'],
#     'raw': 'nine small basketball fields locate in an irregular area .',
#     'imgid': 10213,
#     'sentid': 51066},
#    {'tokens': ['a',
#      'large',
#      'piece',
#      'of',
#      'meadows',
#      'with',
#      'three',
#      'basketball',
#      'fields',
#      'and',
#      'three',
#      'tennis',
#      'courts',
#      'and',
#      'a',
#      'parking',
#      'lot',
#      'are',
#      'near',
#      'a',
#      'road'],
#     'raw': 'a large piece of meadows with three basketball fields and three tennis courts and a parking lot are near a road .',
#     'imgid': 10213,
#     'sentid': 51067},
#    {'tokens': ['many',
#      'kinds',
#      'of',
#      'sports',
#      'fields',
#      'are',
#      'next',
#      'to',
#      'a',
#      'road',
#      'and',
#      'a',
#      'large',
#      'piece',
#      'of',
#      'meadows'],
#     'raw': 'many kinds of sports fields are next to a road and a large piece of meadows .',
#     'imgid': 10213,
#     'sentid': 51068},
#    {'tokens': ['a',
#      'parking',
#      'lot',
#      'with',
#      'three',
#      'tennis',
#      'courts',
#      'are',
#      'next',
#      'to',
#      'a',
#      'wide',
#      'road'],
#     'raw': 'a parking lot with three tennis courts are next to a wide road .',
#     'imgid': 10213,
#     'sentid': 51069}],
#   'split': 'train',
#   'sentids': [51065, 51066, 51067, 51068, 51069],
#   'old_dataset_name': 'dataset_rsicd_modified'},
#  'rsicd_mountain_64.jpg': {'filename': 'mountain_64.jpg',
#   'imgid': 5091,
#   'sentences': [{'tokens': ['there',
#      'is',
#      'a',
#      'mountain',
#      'of',
#      'grayish',
#      'green'],
#     'raw': 'there is a mountain of grayish green .',
#     'imgid': 5091,
#     'sentid': 25455},
#    {'tokens': ['there', 'is', 'a', 'mountain', 'of', 'grayish', 'green'],
#     'raw': 'there is a mountain of grayish green .',
#     'imgid': 5091,
#     'sentid': 25456},
#    {'tokens': ['there', 'is', 'a', 'mountain', 'of', 'grayish', 'green'],
#     'raw': 'there is a mountain of grayish green .',
#     'imgid': 5091,
#     'sentid': 25457},
#    {'tokens': ['here',
#      'stands',
#      'spectacular',
#      'mountains',
#      'covered',
#      'with',
#      'green',
#      'plants'],
#     'raw': 'here stands spectacular mountains covered with green plants .',
#     'imgid': 5091,
#     'sentid': 25458},
#    {'tokens': ['it',
#      'is',
#      'a',
#      'piece',
#      'of',
#      'irregular',
#      'green',
#      'mountains'],
#     'raw': 'it is a piece of irregular green mountains .',
#     'imgid': 5091,
#     'sentid': 25459}],
#   'split': 'train',
#   'sentids': [25455, 25456, 25457, 25458, 25459],
#   'old_dataset_name': 'dataset_rsicd_modified'},
#  'rsicd_baseballfield_149.jpg': {'filename': 'baseballfield_149.jpg',
#   'imgid': 725,
#   'sentences': [{'tokens': ['a',
#      'baseball',
#      'field',
#      'is',
#      'near',
#      'several',
#      'green',
#      'trees'],
#     'raw': 'a baseball field is near several green trees .',
#     'imgid': 725,
#     'sentid': 3625},
#    {'tokens': ['a',
#      'baseball',
#      'field',
#      'is',
#      'near',
#      'several',
#      'green',
#      'trees'],
#     'raw': 'a baseball field is near several green trees .',
#     'imgid': 725,
#     'sentid': 3626},
#    {'tokens': ['a',
#      'baseball',
#      'field',
#      'is',
#      'near',
#      'several',
#      'green',
#      'trees'],
#     'raw': 'a baseball field is near several green trees .',
#     'imgid': 725,
#     'sentid': 3627},
#    {'tokens': ['a',
#      'baseball',
#      'field',
#      'is',
#      'near',
#      'several',
#      'green',
#      'trees'],
#     'raw': 'a baseball field is near several green trees .',
#     'imgid': 725,
#     'sentid': 3628},
#    {'tokens': ['a',
#      'baseball',
#      'field',
#      'is',
#      'near',
#      'several',
#      'green',
#      'trees'],
#     'raw': 'a baseball field is near several green trees .',
#     'imgid': 725,
#     'sentid': 3629}],
#   'split': 'train',
#   'sentids': [3625, 3626, 3627, 3628, 3629],
#   'old_dataset_name': 'dataset_rsicd_modified'},
#  'rsicd_beach_127.jpg': {'filename': 'beach_127.jpg',
#   'imgid': 921,
#   'sentences': [{'tokens': ['white',
#      'beach',
#      'is',
#      'between',
#      'a',
#      'piece',
#      'of',
#      'ocean',
#      'and',
#      'some',
#      'buildings'],
#     'raw': 'white beach is between a piece of ocean and some buildings .',
#     'imgid': 921,
#     'sentid': 4605},
#    {'tokens': ['the',
#      'roaring',
#      'ocean',
#      'waves',
#      'is',
#      'crashing',
#      'along',
#      'the',
#      'beach'],
#     'raw': 'the roaring ocean waves is crashing along the beach .',
#     'imgid': 921,
#     'sentid': 4606},
#    {'tokens': ['the',
#      'roaring',
#      'ocean',
#      'waves',
#      'is',
#      'crashing',
#      'along',
#      'the',
#      'beach'],
#     'raw': 'the roaring ocean waves is crashing along the beach .',
#     'imgid': 921,
#     'sentid': 4607},
#    {'tokens': ['white',
#      'beach',
#      'is',
#      'between',
#      'a',
#      'piece',
#      'of',
#      'ocean',
#      'and',
#      'some',
#      'buildings'],
#     'raw': 'white beach is between a piece of ocean and some buildings .',
#     'imgid': 921,
#     'sentid': 4608},
#    {'tokens': ['white',
#      'beach',
#      'is',
#      'between',
#      'a',
#      'piece',
#      'of',
#      'ocean',
#      'and',
#      'some',
#      'buildings'],
#     'raw': 'white beach is between a piece of ocean and some buildings .',
#     'imgid': 921,
#     'sentid': 4609}],
#   'split': 'train',
#   'sentids': [4605, 4606, 4607, 4608, 4609],
#   'old_dataset_name': 'dataset_rsicd_modified'},
#  'rsicd_industrial_71.jpg': {'filename': 'industrial_71.jpg',
#   'imgid': 4189,
#   'sentences': [{'tokens': ['industrial',
#      'park',
#      'next',
#      'to',
#      'a',
#      'piece',
#      'of',
#      'green',
#      'land'],
#     'raw': 'industrial park next to a piece of green land .',
#     'imgid': 4189,
#     'sentid': 20945},
#    {'tokens': ['the', 'industrial', 'construction', 'very', 'much'],
#     'raw': 'the industrial construction very much .',
#     'imgid': 4189,
#     'sentid': 20946},
#    {'tokens': ['many', 'buildings', 'are', 'in', 'an', 'industrial', 'area'],
#     'raw': 'many buildings are in an industrial area .',
#     'imgid': 4189,
#     'sentid': 20947},
#    {'tokens': ['many', 'buildings', 'are', 'in', 'an', 'industrial', 'area'],
#     'raw': 'many buildings are in an industrial area .',
#     'imgid': 4189,
#     'sentid': 20948},
#    {'tokens': ['industrial',
#      'park',
#      'next',
#      'to',
#      'a',
#      'piece',
#      'of',
#      'green',
#      'land'],
#     'raw': 'industrial park next to a piece of green land .',
#     'imgid': 4189,
#     'sentid': 20949}],
#   'split': 'train',
#   'sentids': [20945, 20946, 20947, 20948, 20949],
#   'old_dataset_name': 'dataset_rsicd_modified'},
#  'rsicd_00282.jpg': {'filename': '00282.jpg',
#   'imgid': 10281,
#   'sentences': [{'tokens': ['this',
#      'large',
#      'area',
#      'has',
#      'a',
#      'beautiful',
#      'environment',
#      'and',
#      'rich',
#      'plants',
#      'and',
#      'a',
#      'river',
#      'passes',
#      'through',
#      'this',
#      'area',
#      'with',
#      'several',
#      'bridges',
#      'above'],
#     'raw': 'this large area has a beautiful environment and rich plants and a river passes through this area with several bridges above .',
#     'imgid': 10281,
#     'sentid': 51405},
#    {'tokens': ['a', 'forked', 'bridge', 'across', 'a', 'big', 'blue', 'river'],
#     'raw': 'a forked bridge across a big blue river .',
#     'imgid': 10281,
#     'sentid': 51406},
#    {'tokens': ['two',
#      'bridges',
#      'are',
#      'on',
#      'a',
#      'black',
#      'river',
#      'with',
#      'many',
#      'buildings',
#      'on',
#      'two',
#      'sides',
#      'of',
#      'it'],
#     'raw': 'two bridges are on a black river with many buildings on two sides of it .',
#     'imgid': 10281,
#     'sentid': 51407},
#    {'tokens': ['a', 'wide', 'river', 'passed', 'under', 'a', 'bridge'],
#     'raw': 'a wide river passed under a bridge .',
#     'imgid': 10281,
#     'sentid': 51408},
#    {'tokens': ['a',
#      'long',
#      'bridge',
#      'is',
#      'on',
#      'a',
#      'wide',
#      'river',
#      'with',
#      'black',
#      'water'],
#     'raw': 'a long bridge is on a wide river with black water .',
#     'imgid': 10281,
#     'sentid': 51409}],
#   'split': 'train',
#   'sentids': [51405, 51406, 51407, 51408, 51409],
#   'old_dataset_name': 'dataset_rsicd_modified'},
#  'ucm_535.jpg': {'filename': '535.tif',
#   'imgid': 534,
#   'sentences': [{'tokens': ['This', 'is', 'a', 'chaparral'],
#     'raw': 'This is a chaparral .',
#     'imgid': 534,
#     'sentid': 2670},
#    {'tokens': ['Lots', 'of', 'plants', 'scattered', 'on', 'the', 'ground.'],
#     'raw': 'Lots of plants scattered on the ground. .',
#     'imgid': 534,
#     'sentid': 2671},
#    {'tokens': ['Lots',
#      'of',
#      'plants',
#      'scattered',
#      'in',
#      'the',
#      'loess',
#      'ground.'],
#     'raw': 'Lots of plants scattered in the loess ground. .',
#     'imgid': 534,
#     'sentid': 2672},
#    {'tokens': ['There',
#      'are',
#      'some',
#      'grey',
#      'plants',
#      'scattered',
#      'on',
#      'the',
#      'ground'],
#     'raw': 'There are some grey plants scattered on the ground .',
#     'imgid': 534,
#     'sentid': 2673},
#    {'tokens': ['Some',
#      'grey',
#      'plants',
#      'are',
#      'scattered',
#      'in',
#      'the',
#      'loess',
#      'ground'],
#     'raw': 'Some grey plants are scattered in the loess ground .',
#     'imgid': 534,
#     'sentid': 2674}],
#   'split': 'train',
#   'sentids': [2670, 2671, 2672, 2673, 2674],
#   'old_dataset_name': 'dataset_ucm_modified'},
#  'rsicd_park_6.jpg': {'filename': 'park_6.jpg',
#   'imgid': 5436,
#   'sentences': [{'tokens': ['the', 'park', 'is', 'surrounded', 'by', 'villas'],
#     'raw': 'the park is surrounded by villas .',
#     'imgid': 5436,
#     'sentid': 27180},
#    {'tokens': ['we',
#      'can',
#      'see',
#      'a',
#      'park',
#      'together',
#      'with',
#      'some',
#      'residential',
#      'buildings'],
#     'raw': 'we can see a park together with some residential buildings .',
#     'imgid': 5436,
#     'sentid': 27181},
#    {'tokens': ['the',
#      'park',
#      'which',
#      'contains',
#      'a',
#      'lake',
#      'and',
#      'forest',
#      'is',
#      'beside',
#      'the',
#      'neighborhood'],
# ...
#      'many',
#      'green',
#      'trees',
#      'are',
#      'in',
#      'a',
#      'resort'],
#     'raw': 'several buildings with a swimming pool and many green trees are in a resort .',
#     'imgid': 7497,
#     'sentid': 37488},
#    {'tokens': ['the',
#      'swimming',
#      'pool',
#      'is',
#      'surrounded',
#      'by',
#      'lush',
#      'trees',
#      'on',
#      'the',
#      'side',
#      'of',
#      'the',
#      'beach',
#      '.'],
#     'raw': 'the swimming pool is surrounded by lush trees,on the side of the beach .',
#     'imgid': 7497,
#     'sentid': 37489}],
#   'split': 'train',
#   'sentids': [37485, 37486, 37487, 37488, 37489],
#   'old_dataset_name': 'dataset_rsicd_modified'},
#  'ucm_1148.jpg': {'filename': '1148.tif',
#   'imgid': 1147,
#   'sentences': [{'tokens': ['An',
#      'intersection',
#      'with',
#      'a',
#      'few',
#      'cars',
#      'on',
#      'the',
#      'road'],
#     'raw': 'An intersection with a few cars on the road .',
#     'imgid': 1147,
#     'sentid': 5735},
#    {'tokens': ['An',
#      'intersection',
#      'with',
#      'some',
#      'houses',
#      'and',
#      'plants',
#      'at',
#      'the',
#      'corners'],
#     'raw': 'An intersection with some houses and plants at the corners .',
#     'imgid': 1147,
#     'sentid': 5736},
#    {'tokens': ['A',
#      'desolate',
#      'intersection',
#      'only',
#      'with',
#      'some',
#      'houses',
#      'and',
#      'plants',
#      'at',
#      'the',
#      'corners'],
#     'raw': 'A desolate intersection only with some houses and plants at the corners .',
#     'imgid': 1147,
#     'sentid': 5737},
#    {'tokens': ['An',
#      'intersection',
#      'with',
#      'two',
#      'roads',
#      'vertical',
#      'to',
#      'each',
#      'other'],
#     'raw': 'An intersection with two roads vertical to each other .',
#     'imgid': 1147,
#     'sentid': 5738},
#    {'tokens': ['An',
#      'intersection',
#      'with',
#      'two',
#      'roads',
#      'vertical',
#      'to',
#      'each',
#      'other'],
#     'raw': 'An intersection with two roads vertical to each other .',
#     'imgid': 1147,
#     'sentid': 5739}],
#   'split': 'train',
#   'sentids': [5735, 5736, 5737, 5738, 5739],
#   'old_dataset_name': 'dataset_ucm_modified'},
#  'rsicd_bareland_29.jpg': {'filename': 'bareland_29.jpg',
#   'imgid': 571,
#   'sentences': [{'tokens': ['the',
#      'bare',
#      'land',
#      'is',
#      'on',
#      'the',
#      'side',
#      'of',
#      'the',
#      'land'],
#     'raw': 'the bare land is on the side of the land.',
#     'imgid': 571,
#     'sentid': 2855},
#    {'tokens': ['many',
#      'dark',
#      'green',
#      'trees',
#      'beside',
#      'the',
#      'large',
#      'bare',
#      'land'],
#     'raw': 'many dark green trees beside the large bare land.',
#     'imgid': 571,
#     'sentid': 2856},
#    {'tokens': ['it', 'is', 'a', 'piece', 'of', 'khaki', 'bare', 'land'],
#     'raw': 'it is a piece of khaki bare land.',
#     'imgid': 571,
#     'sentid': 2857},
#    {'tokens': ['it', 'is', 'a', 'piece', 'of', 'khaki', 'bare', 'land'],
#     'raw': 'it is a piece of khaki bare land.',
#     'imgid': 571,
#     'sentid': 2858},
#    {'tokens': ['the',
#      'bare',
#      'land',
#      'is',
#      'on',
#      'the',
#      'side',
#      'of',
#      'the',
#      'land'],
#     'raw': 'the bare land is on the side of the land.',
#     'imgid': 571,
#     'sentid': 2859}],
#   'split': 'train',
#   'sentids': [2855, 2856, 2857, 2858, 2859],
#   'old_dataset_name': 'dataset_rsicd_modified'},
#  'rsicd_storagetanks_293.jpg': {'filename': 'storagetanks_293.jpg',
#   'imgid': 9435,
#   'sentences': [{'tokens': ['it', 'is', 'a', 'large', 'oil', 'refinery'],
#     'raw': 'it is a large oil refinery .',
#     'imgid': 9435,
#     'sentid': 47175},
#    {'tokens': ['large', 'and', 'small', 'oil', 'storage', 'tanks'],
#     'raw': 'large and small oil storage tanks .',
#     'imgid': 9435,
#     'sentid': 47176},
#    {'tokens': ['many',
#      'storage',
#      'tanks',
#      'are',
#      'in',
#      'a',
#      'factory',
#      'near',
#      'a',
#      'road'],
#     'raw': 'many storage tanks are in a factory near a road .',
#     'imgid': 9435,
#     'sentid': 47177},
#    {'tokens': ['many',
#      'storage',
#      'tanks',
#      'are',
#      'in',
#      'a',
#      'factory',
#      'near',
#      'a',
#      'road'],
#     'raw': 'many storage tanks are in a factory near a road .',
#     'imgid': 9435,
#     'sentid': 47178},
#    {'tokens': ['it', 'is', 'a', 'large', 'oil', 'refinery'],
#     'raw': 'it is a large oil refinery .',
#     'imgid': 9435,
#     'sentid': 47179}],
#   'split': 'train',
#   'sentids': [47175, 47176, 47177, 47178, 47179],
#   'old_dataset_name': 'dataset_rsicd_modified'},
#  'ucm_1991.jpg': {'filename': '1991.tif',
#   'imgid': 1990,
#   'sentences': [{'tokens': ['A',
#      'big',
#      'storage',
#      'tank',
#      'is',
#      'on',
#      'the',
#      'ground',
#      'with',
#      'some',
#      'buildings',
#      'and',
#      'cars',
#      'beside'],
#     'raw': 'A big storage tank is on the ground with some buildings and cars beside .',
#     'imgid': 1990,
#     'sentid': 9950},
#    {'tokens': ['There',
#      'is',
#      'one',
#      'big',
#      'storage',
#      'tank',
#      'on',
#      'the',
#      'ground',
#      'with',
#      'some',
#      'buildings',
#      'and',
#      'cars',
#      'beside'],
#     'raw': 'There is one big storage tank on the ground with some buildings and cars beside .',
#     'imgid': 1990,
#     'sentid': 9951},
#    {'tokens': ['A',
#      'big',
#      'storage',
#      'tank',
#      'is',
#      'on',
#      'the',
#      'ground',
#      'with',
#      'some',
#      'buildings',
#      'and',
#      'cars',
#      'beside'],
#     'raw': 'A big storage tank is on the ground with some buildings and cars beside .',
#     'imgid': 1990,
#     'sentid': 9952},
#    {'tokens': ['There',
#      'is',
#      'a',
#      'white',
#      'storage',
#      'tank',
#      'on',
#      'the',
#      'ground',
#      'with',
#      'some',
#      'buildings',
#      'and',
#      'cars',
#      'beside'],
#     'raw': 'There is a white storage tank on the ground with some buildings and cars beside .',
#     'imgid': 1990,
#     'sentid': 9953},
#    {'tokens': ['A',
#      'big',
#      'storage',
#      'tank',
#      'is',
#      'on',
#      'the',
#      'ground',
#      'with',
#      'some',
#      'buildings',
#      'and',
#      'cars',
#      'beside'],
#     'raw': 'A big storage tank is on the ground with some buildings and cars beside .',
#     'imgid': 1990,
#     'sentid': 9954}],
#   'split': 'train',
#   'sentids': [9950, 9951, 9952, 9953, 9954],
#   'old_dataset_name': 'dataset_ucm_modified'},
#  'rsicd_sparseresidential_294.jpg': {'filename': 'sparseresidential_294.jpg',
#   'imgid': 8516,
#   'sentences': [{'tokens': ['the',
#      'white',
#      'car',
#      'is',
#      'in',
#      'front',
#      'of',
#      'the',
#      'brown',
#      'roof'],
#     'raw': 'the white car is in front of the brown roof .',
#     'imgid': 8516,
#     'sentid': 42580},
#    {'tokens': ['next',
#      'to',
#      'the',
#      'house',
#      'is',
#      'a',
#      'round',
#      'open',
#      'swimming',
#      'pool'],
#     'raw': 'next to the house is a round open swimming pool .',
#     'imgid': 8516,
#     'sentid': 42581},
#    {'tokens': ['a',
#      'brown',
#      'roof',
#      'building',
#      'and',
#      'a',
#      'swimming',
#      'pool',
#      'surrounded',
#      'by',
#      'lawns',
#      'and',
#      'trees'],
#     'raw': 'a brown roof building and a swimming pool surrounded by lawns and trees .',
#     'imgid': 8516,
#     'sentid': 42582},
#    {'tokens': ['there',
#      'was',
#      'a',
#      'brown',
#      'building',
#      'and',
#      'a',
#      'blue',
#      'pool',
#      'a',
#      'few',
#      'trees',
#      'and',
#      'a',
#      'road'],
#     'raw': 'there was a brown building and a blue pool, a few trees and a road .',
#     'imgid': 8516,
#     'sentid': 42583},
#    {'tokens': ['a',
#      'brown',
#      'roof',
#      'building',
#      'and',
#      'a',
#      'swimming',
#      'pool',
#      'surrounded',
#      'by',
#      'lawns',
#      'and',
#      'trees'],
#     'raw': 'a brown roof building and a swimming pool surrounded by lawns and trees .',
#     'imgid': 8516,
#     'sentid': 42584}],
#   'split': 'train',
#   'sentids': [42580, 42581, 42582, 42583, 42584],
#   'old_dataset_name': 'dataset_rsicd_modified'},
#  'rsicd_playground_255.jpg': {'filename': 'playground_255.jpg',
#   'imgid': 6043,
#   'sentences': [{'tokens': ['a',
#      'playground',
#      'with',
#      'a',
#      'football',
#      'field',
#      'in',
#      'it',
#      'is',
#      'surrounded',
#      'by',
#      'several',
#      'buildings',
#      'and',
#      'green',
#      'trees'],
#     'raw': 'a playground with a football field in it is surrounded by several buildings and green trees .',
#     'imgid': 6043,
#     'sentid': 30215},
#    {'tokens': ['a',
#      'playground',
#      'with',
#      'a',
#      'football',
#      'field',
#      'in',
#      'it',
#      'is',
#      'surrounded',
#      'by',
#      'several',
#      'buildings',
#      'and',
#      'green',
#      'trees'],
#     'raw': 'a playground with a football field in it is surrounded by several buildings and green trees .',
#     'imgid': 6043,
#     'sentid': 30216},
#    {'tokens': ['a',
#      'playground',
#      'with',
#      'a',
#      'football',
#      'field',
#      'in',
#      'it',
#      'is',
#      'surrounded',
#      'by',
#      'several',
#      'buildings',
#      'and',
#      'green',
#      'trees'],
#     'raw': 'a playground with a football field in it is surrounded by several buildings and green trees .',
#     'imgid': 6043,
#     'sentid': 30217},
#    {'tokens': ['a',
#      'playground',
#      'with',
#      'a',
#      'football',
#      'field',
#      'in',
#      'it',
#      'is',
#      'surrounded',
#      'by',
#      'several',
#      'buildings',
#      'and',
#      'green',
#      'trees'],
#     'raw': 'a playground with a football field in it is surrounded by several buildings and green trees .',
#     'imgid': 6043,
#     'sentid': 30218},
#    {'tokens': ['a',
#      'playground',
#      'with',
#      'a',
#      'football',
#      'field',
#      'in',
#      'it',
#      'is',
#      'surrounded',
#      'by',
#      'several',
#      'buildings',
#      'and',
#      'green',
#      'trees'],
#     'raw': 'a playground with a football field in it is surrounded by several buildings and green trees .',
#     'imgid': 6043,
#     'sentid': 30219}],
#   'split': 'train',
#   'sentids': [30215, 30216, 30217, 30218, 30219],
#   'old_dataset_name': 'dataset_rsicd_modified'},
#  'rsicd_airport_173.jpg': {'filename': 'airport_173.jpg',
#   'imgid': 82,
#   'sentences': [{'tokens': ['many',
#      'planes',
#      'are',
#      'in',
#      'an',
#      'airport',
#      'near',
#      'many',
#      'buildings'],
#     'raw': 'many planes are in an airport near many buildings .',
#     'imgid': 82,
#     'sentid': 410},
#    {'tokens': ['many',
#      'planes',
#      'are',
#      'in',
#      'an',
#      'airport',
#      'near',
#      'many',
#      'buildings'],
#     'raw': 'many planes are in an airport near many buildings .',
#     'imgid': 82,
#     'sentid': 411},
#    {'tokens': ['many',
#      'planes',
#      'are',
#      'in',
#      'an',
#      'airport',
#      'near',
#      'many',
#      'buildings'],
#     'raw': 'many planes are in an airport near many buildings .',
#     'imgid': 82,
#     'sentid': 412},
#    {'tokens': ['many',
#      'planes',
#      'are',
#      'in',
#      'an',
#      'airport',
#      'near',
#      'many',
#      'buildings'],
#     'raw': 'many planes are in an airport near many buildings .',
#     'imgid': 82,
#     'sentid': 413},
#    {'tokens': ['many',
#      'planes',
#      'are',
#      'in',
#      'an',
#      'airport',
#      'near',
#      'many',
#      'buildings'],
#     'raw': 'many planes are in an airport near many buildings .',
#     'imgid': 82,
#     'sentid': 414}],
#   'split': 'train',
#   'sentids': [410, 411, 412, 413, 414],
#   'old_dataset_name': 'dataset_rsicd_modified'},
#  'rsicd_railwaystation_98.jpg': {'filename': 'railwaystation_98.jpg',
#   'imgid': 7298,
#   'sentences': [{'tokens': ['rail', 'extending', 'in', 'all', 'directions'],
#     'raw': 'rail extending in all directions .',
#     'imgid': 7298,
#     'sentid': 36490},
#    {'tokens': ['to',
#      'benefit',
#      'from',
#      'a',
#      'train',
#      'station',
#      'to',
#      'car',
#      'very',
#      'much',
#      'alive'],
#     'raw': 'to benefit from a train station to car very much alive .',
#     'imgid': 7298,
#     'sentid': 36491},
#    {'tokens': ['many',
#      'buildings',
#      'are',
#      'in',
#      'two',
#      'sides',
#      'of',
#      'a',
#      'railway',
#      'station'],
#     'raw': 'many buildings are in two sides of a railway station .',
#     'imgid': 7298,
#     'sentid': 36492},
#    {'tokens': ['many',
#      'buildings',
#      'are',
#      'in',
#      'two',
#      'sides',
#      'of',
#      'a',
#      'railway',
#      'station'],
#     'raw': 'many buildings are in two sides of a railway station .',
#     'imgid': 7298,
#     'sentid': 36493},
#    {'tokens': ['rail', 'extending', 'in', 'all', 'directions'],
#     'raw': 'rail extending in all directions .',
#     'imgid': 7298,
#     'sentid': 36494}],
#   'split': 'train',
#   'sentids': [36490, 36491, 36492, 36493, 36494],
#   'old_dataset_name': 'dataset_rsicd_modified'},
#  'rsicd_river_227.jpg': {'filename': 'river_227.jpg',
#   'imgid': 7732,
#   'sentences': [{'tokens': ['the',
#      'brown',
#      'saddle',
#      'shaped',
#      'river',
#      'is',
#      'across',
#      'the',
#      'dense',
#      'forest'],
#     'raw': 'the brown saddle shaped river is across the dense forest .',
#     'imgid': 7732,
#     'sentid': 38660},
#    {'tokens': ['the',
#      'brown',
#      'river',
#      'takes',
#      'a',
#      'sudden',
#      'turn',
#      'in',
#      'the',
#      'rainforest'],
#     'raw': 'the brown river takes a sudden turn in the rainforest .',
#     'imgid': 7732,
#     'sentid': 38661},
#    {'tokens': ['the',
#      'brown',
#      'saddle',
#      'shaped',
#      'river',
#      'is',
#      'across',
#      'the',
#      'dense',
#      'forest'],
#     'raw': 'the brown saddle shaped river is across the dense forest .',
#     'imgid': 7732,
#     'sentid': 38662},
#    {'tokens': ['it',
#      'is',
#      'a',
#      'rather',
#      'brown',
#      'u',
#      'shaped',
#      'river',
#      'passing',
#      'by',
#      'the',
#      'lush',
#      'forest'],
#     'raw': 'it is a rather brown u shaped river passing by the lush forest .',
#     'imgid': 7732,
#     'sentid': 38663},
#    {'tokens': ['many',
#      'green',
#      'trees',
#      'are',
#      'in',
#      'two',
#      'sides',
#      'of',
#      'a',
#      'curved',
#      'brown',
#      'river'],
#     'raw': 'many green trees are in two sides of a curved brown river .',
#     'imgid': 7732,
#     'sentid': 38664}],
#   'split': 'train',
#   'sentids': [38660, 38661, 38662, 38663, 38664],
#   'old_dataset_name': 'dataset_rsicd_modified'},
#  'rsicd_00027.jpg': {'filename': '00027.jpg',
#   'imgid': 10026,
#   'sentences': [{'tokens': ['a',
#      'football',
#      'field',
#      'is',
#      'embraced',
#      'with',
#      'abundant',
#      'plants',
#      'while',
#      'several',
#      'high-rise',
#      'buildings',
#      'aside'],
#     'raw': 'a football field is embraced with abundant plants while several high-rise buildings aside .',
#     'imgid': 10026,
#     'sentid': 50130},
#    {'tokens': ['a',
#      'green',
#      'football',
#      'court',
#      'and',
#      'a',
#      'tall',
#      'building',
#      'with',
#      'yellow',
#      'paint',
#      'beside'],
#     'raw': 'a green football court and a tall building with yellow paint beside .',
#     'imgid': 10026,
#     'sentid': 50131},
#    {'tokens': ['many',
#      'buildings',
#      'and',
#      'green',
#      'trees',
#      'are',
#      'around',
#      'a',
#      'playground'],
#     'raw': 'many buildings and green trees are around a playground .',
#     'imgid': 10026,
#     'sentid': 50132},
#    {'tokens': ['a',
#      'playground',
#      'is',
#      'surrounded',
#      'by',
#      'trees',
#      'and',
#      'buildings'],
#     'raw': 'a playground is surrounded by trees and buildings',
#     'imgid': 10026,
#     'sentid': 50133},
#    {'tokens': ['a',
#      'playground',
#      'is',
#      'surrounded',
#      'by',
#      'many',
#      'green',
#      'trees',
#      'and',
#      'buildings'],
#     'raw': 'a playground is surrounded by many green trees and buildings .',
#     'imgid': 10026,
#     'sentid': 50134}],
#   'split': 'train',
#   'sentids': [50130, 50131, 50132, 50133, 50134],
#   'old_dataset_name': 'dataset_rsicd_modified'},
#  ...}
