# %%
import json
import numpy as np
import pandas as pd
from collections import defaultdict
from functools import reduce
from sklearn.model_selection import train_test_split

# %%
json_data = {}
sizes = {}
set_name = ['rsicd', 'ucm', 'sydney']

# read in json files from all three datasets
for name in set_name:
    with open('../data/raw/dataset_' + name + '_modified.json', 'r') as data:
        json_data[name] = json.load(data)
        sizes[name] = len(json_data[name]['images'])
        print(f'There are {sizes[name]} images in the {name} dataset.')
# Out:
# There are 10921 images in the rsicd dataset.
# There are 2100 images in the ucm dataset.
# There are 613 images in the sydney dataset.

# %%
ucm_data = {}
sydney_data = {}
rsicd_data = {}

for name in set_name:
    for single_image in json_data[name]['images']:
        new_filename = name + '_' + single_image['filename'][:-3] + 'jpg'
        if (name == 'rsicd'):
            rsicd_data[new_filename] = single_image
            rsicd_data[new_filename]['old_dataset_name'] = 'dataset_rsicd_modified'
        elif (name == 'ucm'):
            ucm_data[new_filename] = single_image
            ucm_data[new_filename]['old_dataset_name'] = 'dataset_ucm_modified'
        elif (name == 'sydney'):
            sydney_data[new_filename] = single_image
            sydney_data[new_filename]['old_dataset_name'] = 'dataset_sydney_modified'
        else: 
            print("uh-oh") #should add try catch later
            
print(f'There are {len(rsicd_data)} images in the rsicd dataset.')
print(f'There are {len(ucm_data)} images in the ucm dataset.')
print(f'There are {len(sydney_data)} images in the sydney dataset.')
# Out:
# There are 10921 images in the rsicd dataset.
# There are 2100 images in the ucm dataset.
# There are 613 images in the sydney dataset.

# %%
# Python code to merge dict 
def merge_2(dict1, dict2, dict3):
    dict2.update(dict1)
    return(dict3.update(dict2)) 

def merge(dict1, dict2, dict3): 
    res = {**dict1, **dict2, **dict3} 
    return res

# %%
combined_data = merge(rsicd_data, ucm_data, sydney_data)

# %%
len(combined_data)
# Out:
# 13634

# %%
combined_df = pd.DataFrame(combined_data).T

# %%
combined_df.head(-5)
# Out:
#                               filename imgid  \
# rsicd_airport_1.jpg      airport_1.jpg     0
# rsicd_airport_10.jpg    airport_10.jpg     1
# rsicd_airport_100.jpg  airport_100.jpg     2
# rsicd_airport_101.jpg  airport_101.jpg     3
# rsicd_airport_102.jpg  airport_102.jpg     4
# ...                                ...   ...
# sydney_604.jpg                 604.tif   603
# sydney_605.jpg                 605.tif   604
# sydney_606.jpg                 606.tif   605
# sydney_607.jpg                 607.tif   606
# sydney_608.jpg                 608.tif   607
#
#                                                                sentences  \
# rsicd_airport_1.jpg    [{'tokens': ['many', 'planes', 'are', 'parked'...
# rsicd_airport_10.jpg   [{'tokens': ['some', 'planes', 'are', 'parked'...
# rsicd_airport_100.jpg  [{'tokens': ['many', 'planes', 'are', 'parked'...
# rsicd_airport_101.jpg  [{'tokens': ['many', 'planes', 'are', 'parked'...
# rsicd_airport_102.jpg  [{'tokens': ['several', 'buildings', 'and', 'g...
# ...                                                                  ...
# sydney_604.jpg         [{'tokens': ['There', 'is', 'a', 'wide', 'runw...
# sydney_605.jpg         [{'tokens': ['A', 'narrow', 'runway', 'with', ...
# sydney_606.jpg         [{'tokens': ['A', 'wide', 'runway', 'with', 'w...
# sydney_607.jpg         [{'tokens': ['A', 'straight', 'runway', 'with'...
# sydney_608.jpg         [{'tokens': ['A', 'narrow', 'runway', 'with', ...
#
#                        split                         sentids  \
# rsicd_airport_1.jpg    train                 [0, 1, 2, 3, 4]
# rsicd_airport_10.jpg   train                 [5, 6, 7, 8, 9]
# rsicd_airport_100.jpg  train            [10, 11, 12, 13, 14]
# rsicd_airport_101.jpg  train            [15, 16, 17, 18, 19]
# rsicd_airport_102.jpg  train            [20, 21, 22, 23, 24]
# ...                      ...                             ...
# sydney_604.jpg           val  [3015, 3016, 3017, 3018, 3019]
# sydney_605.jpg           val  [3020, 3021, 3022, 3023, 3024]
# sydney_606.jpg           val  [3025, 3026, 3027, 3028, 3029]
# sydney_607.jpg           val  [3030, 3031, 3032, 3033, 3034]
# sydney_608.jpg          test  [3035, 3036, 3037, 3038, 3039]
#
#                               old_dataset_name
# rsicd_airport_1.jpg     dataset_rsicd_modified
# rsicd_airport_10.jpg    dataset_rsicd_modified
# rsicd_airport_100.jpg   dataset_rsicd_modified
# rsicd_airport_101.jpg   dataset_rsicd_modified
# rsicd_airport_102.jpg   dataset_rsicd_modified
# ...                                        ...
# sydney_604.jpg         dataset_sydney_modified
# sydney_605.jpg         dataset_sydney_modified
# sydney_606.jpg         dataset_sydney_modified
# sydney_607.jpg         dataset_sydney_modified
# sydney_608.jpg         dataset_sydney_modified
#
# [13629 rows x 6 columns]

# %%
train_valid, test = train_test_split(combined_df, test_size=0.2, random_state=123)
train, valid = train_test_split(train_valid, test_size=0.2, random_state=123)

# %%
len(train)
# Out:
# 8725

# %%
len(test)
# Out:
# 2727

# %%
len(valid)
# Out:
# 2182

# %%
train.head()
# Out:
#                               filename imgid  \
# rsicd_church_212.jpg    church_212.jpg  2036
# rsicd_church_145.jpg    church_145.jpg  1961
# sydney_333.jpg                 333.tif   332
# rsicd_farmland_12.jpg  farmland_12.jpg  3233
# rsicd_beach_161.jpg      beach_161.jpg   959
#
#                                                                sentences  \
# rsicd_church_212.jpg   [{'tokens': ['some', 'buildings', 'and', 'many...
# rsicd_church_145.jpg   [{'tokens': ['a', 'church', 'is', 'near', 'a',...
# sydney_333.jpg         [{'tokens': ['A', 'curved', 'river', 'with', '...
# rsicd_farmland_12.jpg  [{'tokens': ['several', 'pieces', 'of', 'farml...
# rsicd_beach_161.jpg    [{'tokens': ['two', 'rows', 'of', 'waves', 'in...
#
#                        split                              sentids  \
# rsicd_church_212.jpg   train  [10180, 10181, 10182, 10183, 10184]
# rsicd_church_145.jpg   train       [9805, 9806, 9807, 9808, 9809]
# sydney_333.jpg         train       [1660, 1661, 1662, 1663, 1664]
# rsicd_farmland_12.jpg  train  [16165, 16166, 16167, 16168, 16169]
# rsicd_beach_161.jpg    train       [4795, 4796, 4797, 4798, 4799]
#
#                               old_dataset_name
# rsicd_church_212.jpg    dataset_rsicd_modified
# rsicd_church_145.jpg    dataset_rsicd_modified
# sydney_333.jpg         dataset_sydney_modified
# rsicd_farmland_12.jpg   dataset_rsicd_modified
# rsicd_beach_161.jpg     dataset_rsicd_modified

# %%
test.head()
# Out:
#                                   filename  imgid  \
# ucm_1704.jpg                      1704.tif   1703
# rsicd_meadow_272.jpg        meadow_272.jpg   4412
# rsicd_00666.jpg                  00666.jpg  10665
# rsicd_viaduct_414.jpg      viaduct_414.jpg   9930
# rsicd_industrial_52.jpg  industrial_52.jpg   4168
#
#                                                                  sentences  \
# ucm_1704.jpg             [{'tokens': ['It', 'is', 'a', 'straight', 'run...
# rsicd_meadow_272.jpg     [{'tokens': ['the', 'meadow', 'is', 'green', '...
# rsicd_00666.jpg          [{'tokens': ['the', 'grass', 'with', 'a', 'sma...
# rsicd_viaduct_414.jpg    [{'tokens': ['the', 'viaducts', 'crisscross', ...
# rsicd_industrial_52.jpg  [{'tokens': ['there', 'is', 'a', 'viaduct', 'b...
#
#                          split                              sentids  \
# ucm_1704.jpg             train       [8515, 8516, 8517, 8518, 8519]
# rsicd_meadow_272.jpg     train  [22060, 22061, 22062, 22063, 22064]
# rsicd_00666.jpg          train  [53325, 53326, 53327, 53328, 53329]
# rsicd_viaduct_414.jpg      val  [49650, 49651, 49652, 49653, 49654]
# rsicd_industrial_52.jpg    val  [20840, 20841, 20842, 20843, 20844]
#
#                                old_dataset_name
# ucm_1704.jpg               dataset_ucm_modified
# rsicd_meadow_272.jpg     dataset_rsicd_modified
# rsicd_00666.jpg          dataset_rsicd_modified
# rsicd_viaduct_414.jpg    dataset_rsicd_modified
# rsicd_industrial_52.jpg  dataset_rsicd_modified

# %%
valid.head()
# Out:
#                                     filename imgid  \
# ucm_1029.jpg                        1029.tif  1028
# rsicd_park_282.jpg              park_282.jpg  5333
# rsicd_bridge_306.jpg          bridge_306.jpg  1520
# rsicd_playground_155.jpg  playground_155.jpg  5932
# rsicd_mountain_330.jpg      mountain_330.jpg  5047
#
#                                                                   sentences  \
# ucm_1029.jpg              [{'tokens': ['Lots', 'of', 'boats', 'docked', ...
# rsicd_park_282.jpg        [{'tokens': ['a', 'park', 'with', 'some', 'gre...
# rsicd_bridge_306.jpg      [{'tokens': ['a', 'long', 'bridge', 'is', 'bet...
# rsicd_playground_155.jpg  [{'tokens': ['some', 'trees', 'are', 'near', '...
# rsicd_mountain_330.jpg    [{'tokens': ['some', 'part', 'of', 'the', 'mou...
#
#                           split                              sentids  \
# ucm_1029.jpg              train       [5140, 5141, 5142, 5143, 5144]
# rsicd_park_282.jpg        train  [26665, 26666, 26667, 26668, 26669]
# rsicd_bridge_306.jpg      train       [7600, 7601, 7602, 7603, 7604]
# rsicd_playground_155.jpg  train  [29660, 29661, 29662, 29663, 29664]
# rsicd_mountain_330.jpg    train  [25235, 25236, 25237, 25238, 25239]
#
#                                 old_dataset_name
# ucm_1029.jpg                dataset_ucm_modified
# rsicd_park_282.jpg        dataset_rsicd_modified
# rsicd_bridge_306.jpg      dataset_rsicd_modified
# rsicd_playground_155.jpg  dataset_rsicd_modified
# rsicd_mountain_330.jpg    dataset_rsicd_modified

# %%
train_dict = train.to_dict(orient='index')
test_dict = test.to_dict(orient='index')
valid_dict = valid.to_dict(orient='index')

# %%
# In each of the images add the current set name key-value pair
new_set_name = ['train', 'test', 'valid']
for name in new_set_name:
    if (name == 'train'):
        for key, value in train_dict.items():
            value['current_set_name'] = name
    elif (name == 'test'):
        for key, value in test_dict.items():
            value['current_set_name'] = name
    elif (name == 'valid'):
        for key, value in valid_dict.items():
            value['current_set_name'] = name
    else:
        print("uh-oh")

# %%
imgs_names = [(train_dict, 'train', train), 
              (valid_dict, 'valid', valid), 
              (test_dict, 'test', test)]

# %%
for imgs, name, _ in imgs_names:
    with open('../data/processed/json/' + name + '.json', 'w') as file:
        json.dump(imgs, file)

# %%
train_dict
# Out:
# {'rsicd_church_212.jpg': {'filename': 'church_212.jpg',
#   'imgid': 2036,
#   'sentences': [{'tokens': ['some',
#      'buildings',
#      'and',
#      'many',
#      'green',
#      'trees',
#      'are',
#      'around',
#      'a',
#      'gray',
#      'church'],
#     'raw': 'some buildings and many green trees are around a gray church .',
#     'imgid': 2036,
#     'sentid': 10180},
#    {'tokens': ['some',
#      'buildings',
#      'and',
#      'many',
#      'green',
#      'trees',
#      'are',
#      'around',
#      'a',
#      'gray',
#      'church'],
#     'raw': 'some buildings and many green trees are around a gray church .',
#     'imgid': 2036,
#     'sentid': 10181},
#    {'tokens': ['some',
#      'buildings',
#      'and',
#      'many',
#      'green',
#      'trees',
#      'are',
#      'around',
#      'a',
#      'gray',
#      'church'],
#     'raw': 'some buildings and many green trees are around a gray church .',
#     'imgid': 2036,
#     'sentid': 10182},
#    {'tokens': ['some',
#      'buildings',
#      'and',
#      'many',
#      'green',
#      'trees',
#      'are',
#      'around',
#      'a',
#      'gray',
#      'church'],
#     'raw': 'some buildings and many green trees are around a gray church .',
#     'imgid': 2036,
#     'sentid': 10183},
#    {'tokens': ['some',
#      'buildings',
#      'and',
#      'many',
#      'green',
#      'trees',
#      'are',
#      'around',
#      'a',
#      'gray',
#      'church'],
#     'raw': 'some buildings and many green trees are around a gray church .',
#     'imgid': 2036,
#     'sentid': 10184}],
#   'split': 'train',
#   'sentids': [10180, 10181, 10182, 10183, 10184],
#   'old_dataset_name': 'dataset_rsicd_modified',
#   'current_set_name': 'train'},
#  'rsicd_church_145.jpg': {'filename': 'church_145.jpg',
#   'imgid': 1961,
#   'sentences': [{'tokens': ['a',
#      'church',
#      'is',
#      'near',
#      'a',
#      'river',
#      'with',
#      'some',
#      'buildings',
#      'and',
#      'green',
#      'trees'],
#     'raw': 'a church is near a river with some buildings and green trees .',
#     'imgid': 1961,
#     'sentid': 9805},
#    {'tokens': ['a',
#      'church',
#      'is',
#      'near',
#      'a',
#      'river',
#      'with',
#      'some',
#      'buildings',
#      'and',
#      'green',
#      'trees'],
#     'raw': 'a church is near a river with some buildings and green trees .',
#     'imgid': 1961,
#     'sentid': 9806},
#    {'tokens': ['a',
#      'church',
#      'is',
#      'near',
#      'a',
#      'river',
#      'with',
#      'some',
#      'buildings',
#      'and',
#      'green',
#      'trees'],
#     'raw': 'a church is near a river with some buildings and green trees .',
#     'imgid': 1961,
#     'sentid': 9807},
#    {'tokens': ['a',
#      'church',
#      'is',
#      'near',
#      'a',
#      'river',
#      'with',
#      'some',
#      'buildings',
#      'and',
#      'green',
#      'trees'],
#     'raw': 'a church is near a river with some buildings and green trees .',
#     'imgid': 1961,
#     'sentid': 9808},
#    {'tokens': ['a',
#      'church',
#      'is',
#      'near',
#      'a',
#      'river',
#      'with',
#      'some',
#      'buildings',
#      'and',
#      'green',
#      'trees'],
#     'raw': 'a church is near a river with some buildings and green trees .',
#     'imgid': 1961,
#     'sentid': 9809}],
#   'split': 'train',
#   'sentids': [9805, 9806, 9807, 9808, 9809],
#   'old_dataset_name': 'dataset_rsicd_modified',
#   'current_set_name': 'train'},
#  'sydney_333.jpg': {'filename': '333.tif',
#   'imgid': 332,
#   'sentences': [{'tokens': ['A',
#      'curved',
#      'river',
#      'with',
#      'dark',
#      'green',
#      'waters',
#      'go',
#      'through',
#      'a',
#      'meadow'],
#     'raw': 'A curved river with dark green waters go through a meadow .',
#     'imgid': 332,
#     'sentid': 1660},
#    {'tokens': ['There',
#      'are',
#      'some',
#      'dense',
#      'plants',
#      'on',
#      'both',
#      'sides',
#      'of',
#      'a',
#      'curved',
#      'river'],
#     'raw': 'There are some dense plants on both sides of a curved river .',
#     'imgid': 332,
#     'sentid': 1661},
#    {'tokens': ['A',
#      'curved',
#      'river',
#      'with',
#      'dark',
#      'green',
#      'waters',
#      'and',
#      'dense',
#      'plants',
#      'on',
#      'both',
#      'sides'],
#     'raw': 'A curved river with dark green waters and dense plants on both sides .',
#     'imgid': 332,
#     'sentid': 1662},
#    {'tokens': ['Some',
#      'green',
#      'plants',
#      'on',
#      'both',
#      'sides',
#      'of',
#      'a',
#      'curved',
#      'river'],
#     'raw': 'Some green plants on both sides of a curved river .',
#     'imgid': 332,
#     'sentid': 1663},
#    {'tokens': ['A',
#      'curved',
#      'river',
#      'with',
#      'dark',
#      'green',
#      'waters',
#      'and',
#      'dense',
#      'plants',
#      'on',
#      'both',
#      'side'],
#     'raw': 'A curved river with dark green waters and dense plants on both side .',
#     'imgid': 332,
#     'sentid': 1664}],
#   'split': 'train',
#   'sentids': [1660, 1661, 1662, 1663, 1664],
#   'old_dataset_name': 'dataset_sydney_modified',
#   'current_set_name': 'train'},
#  'rsicd_farmland_12.jpg': {'filename': 'farmland_12.jpg',
#   'imgid': 3233,
#   'sentences': [{'tokens': ['several',
#      'pieces',
#      'of',
#      'farmland',
#      's',
#      'are',
#      'together'],
#     'raw': 'several pieces of farmland s are together .',
#     'imgid': 3233,
#     'sentid': 16165},
#    {'tokens': ['the',
#      'textures',
#      'in',
#      'the',
#      'farmland',
#      'are',
#      'very',
#      'beautiful'],
#     'raw': 'the textures in the farmland are very beautiful .',
#     'imgid': 3233,
#     'sentid': 16166},
#    {'tokens': ['the',
#      'textures',
#      'in',
#      'the',
#      'farmland',
#      'are',
#      'very',
#      'beautiful'],
#     'raw': 'the textures in the farmland are very beautiful .',
#     'imgid': 3233,
#     'sentid': 16167},
#    {'tokens': ['several', 'pieces', 'of', 'farmland', 's', 'are', 'together'],
#     'raw': 'several pieces of farmland s are together .',
#     'imgid': 3233,
#     'sentid': 16168},
#    {'tokens': ['several', 'pieces', 'of', 'farmland', 's', 'are', 'together'],
#     'raw': 'several pieces of farmland s are together .',
#     'imgid': 3233,
#     'sentid': 16169}],
#   'split': 'train',
#   'sentids': [16165, 16166, 16167, 16168, 16169],
#   'old_dataset_name': 'dataset_rsicd_modified',
#   'current_set_name': 'train'},
#  'rsicd_beach_161.jpg': {'filename': 'beach_161.jpg',
#   'imgid': 959,
#   'sentences': [{'tokens': ['two',
#      'rows',
#      'of',
#      'waves',
#      'in',
#      'green',
#      'ocean',
#      'are',
#      'near',
#      'a',
#      'yellow',
#      'beach'],
#     'raw': 'two rows of waves in green ocean are near a yellow beach .',
#     'imgid': 959,
#     'sentid': 4795},
#    {'tokens': ['two',
#      'rows',
#      'of',
#      'waves',
#      'in',
#      'green',
#      'ocean',
#      'are',
#      'near',
#      'a',
#      'yellow',
#      'beach'],
#     'raw': 'two rows of waves in green ocean are near a yellow beach .',
#     'imgid': 959,
#     'sentid': 4796},
#    {'tokens': ['two',
#      'rows',
#      'of',
#      'waves',
#      'in',
#      'green',
#      'ocean',
#      'are',
#      'near',
#      'a',
#      'yellow',
#      'beach'],
#     'raw': 'two rows of waves in green ocean are near a yellow beach .',
#     'imgid': 959,
#     'sentid': 4797},
#    {'tokens': ['two',
#      'rows',
#      'of',
#      'waves',
#      'in',
#      'green',
#      'ocean',
#      'are',
#      'near',
#      'a',
#      'yellow',
#      'beach'],
#     'raw': 'two rows of waves in green ocean are near a yellow beach .',
#     'imgid': 959,
#     'sentid': 4798},
#    {'tokens': ['two',
#      'rows',
#      'of',
#      'waves',
#      'in',
#      'green',
#      'ocean',
#      'are',
#      'near',
#      'a',
#      'yellow',
#      'beach'],
#     'raw': 'two rows of waves in green ocean are near a yellow beach .',
#     'imgid': 959,
#     'sentid': 4799}],
#   'split': 'train',
#   'sentids': [4795, 4796, 4797, 4798, 4799],
#   'old_dataset_name': 'dataset_rsicd_modified',
#   'current_set_name': 'train'},
#  'ucm_1246.jpg': {'filename': '1246.tif',
#   'imgid': 1245,
#   'sentences': [{'tokens': ['It', 'is', 'a', 'medium', 'residential', 'area'],
#     'raw': 'It is a medium residential area .',
#     'imgid': 1245,
#     'sentid': 6225},
#    {'tokens': ['A',
#      'medium',
#      'residential',
#      'area',
#      'with',
#      'houses',
#      'arranged',
#      'neatly'],
#     'raw': 'A medium residential area with houses arranged neatly .',
#     'imgid': 1245,
#     'sentid': 6226},
#    {'tokens': ['A',
#      'medium',
#      'residential',
#      'area',
#      'with',
#      'a',
#      'road',
#      'goes',
#      'through',
#      'this',
#      'area'],
#     'raw': 'A medium residential area with a road goes through this area .',
#     'imgid': 1245,
#     'sentid': 6227},
#    {'tokens': ['Some',
#      'houses',
#      'arranged',
#      'neatly',
#      'in',
#      'the',
#      'medium',
#      'residential',
#      'area'],
#     'raw': 'Some houses arranged neatly in the medium residential area .',
#     'imgid': 1245,
#     'sentid': 6228},
#    {'tokens': ['This',
#      'is',
#      'a',
#      'medium',
#      'residential',
#      'area',
#      'with',
#      'a',
#      'road',
#      'goes',
#      'through',
#      'this',
#      'area'],
#     'raw': 'This is a medium residential area with a road goes through this area .',
#     'imgid': 1245,
#     'sentid': 6229}],
#   'split': 'train',
#   'sentids': [6225, 6226, 6227, 6228, 6229],
#   'old_dataset_name': 'dataset_ucm_modified',
#   'current_set_name': 'train'},
#  'rsicd_sparseresidential_227.jpg': {'filename': 'sparseresidential_227.jpg',
#   'imgid': 8442,
#   'sentences': [{'tokens': ['a',
#      'building',
#      'with',
#      'a',
#      'swimming',
#      'pool',
#      'is',
#      'surrounded',
#      'by',
#      'some',
#      'green',
#      'trees',
#      'and',
#      'meadows'],
#     'raw': 'a building with a swimming pool is surrounded by some green trees and meadows .',
#     'imgid': 8442,
#     'sentid': 42210},
#    {'tokens': ['a',
#      'building',
#      'with',
#      'a',
#      'swimming',
#      'pool',
#      'is',
#      'surrounded',
#      'by',
#      'some',
#      'green',
#      'trees',
#      'and',
#      'meadows'],
#     'raw': 'a building with a swimming pool is surrounded by some green trees and meadows .',
#     'imgid': 8442,
#     'sentid': 42211},
#    {'tokens': ['a',
#      'building',
#      'with',
#      'a',
#      'swimming',
#      'pool',
#      'is',
#      'surrounded',
#      'by',
#      'some',
#      'green',
#      'trees',
#      'and',
#      'meadows'],
#     'raw': 'a building with a swimming pool is surrounded by some green trees and meadows .',
#     'imgid': 8442,
#     'sentid': 42212},
#    {'tokens': ['a',
#      'building',
#      'with',
#      'a',
#      'swimming',
#      'pool',
#      'is',
#      'surrounded',
#      'by',
#      'some',
#      'green',
#      'trees',
#      'and',
#      'meadows'],
#     'raw': 'a building with a swimming pool is surrounded by some green trees and meadows .',
#     'imgid': 8442,
#     'sentid': 42213},
#    {'tokens': ['a',
#      'building',
#      'with',
#      'a',
#      'swimming',
#      'pool',
#      'is',
#      'surrounded',
#      'by',
#      'some',
#      'green',
#      'trees',
#      'and',
#      'meadows'],
#     'raw': 'a building with a swimming pool is surrounded by some green trees and meadows .',
#     'imgid': 8442,
#     'sentid': 42214}],
#   'split': 'train',
#   'sentids': [42210, 42211, 42212, 42213, 42214],
#   'old_dataset_name': 'dataset_rsicd_modified',
#   'current_set_name': 'train'},
#  'ucm_107.jpg': {'filename': '107.tif',
#   'imgid': 106,
#   'sentences': [{'tokens': ['Two',
#      'airplanes',
#      'are',
#      'surrounded',
#      'with',
#      'some',
#      'cars'],
#     'raw': 'Two airplanes are surrounded with some cars .',
#     'imgid': 106,
#     'sentid': 530},
#    {'tokens': ['There', 'are', 'two', 'airplanes', 'in', 'the', 'airport'],
#     'raw': 'There are two airplanes in the airport .',
#     'imgid': 106,
#     'sentid': 531},
#    {'tokens': ['Two', 'airplanes', 'are', 'stopped', 'at', 'the', 'airport'],
#     'raw': 'Two airplanes are stopped at the airport .',
#     'imgid': 106,
#     'sentid': 532},
#    {'tokens': ['Two',
#      'airplanes',
#      'are',
#      'surrounded',
#      'with',
#      'some',
#      'cars',
#      'in',
#      'the',
#      'airport'],
#     'raw': 'Two airplanes are surrounded with some cars in the airport .',
#     'imgid': 106,
#     'sentid': 533},
#    {'tokens': ['Two',
#      'airplanes',
#      'are',
#      'surrounded',
#      'with',
#      'some',
#      'cars',
#      'in',
#      'the',
#      'airport'],
#     'raw': 'Two airplanes are surrounded with some cars in the airport .',
#     'imgid': 106,
#     'sentid': 534}],
#   'split': 'train',
#   'sentids': [530, 531, 532, 533, 534],
#   'old_dataset_name': 'dataset_ucm_modified',
#   'current_set_name': 'train'},
#  'rsicd_pond_60.jpg': {'filename': 'pond_60.jpg',
#   'imgid': 6617,
#   'sentences': [{'tokens': ['there',
#      'is',
#      'a',
#      'pond',
#      'with',
#      'green',
#      'water',
#      'surrounded',
#      'by',
#      'trees',
#      'and',
#      'some',
#      'houses'],
#     'raw': 'there is a pond with green water surrounded by trees and some houses .',
#     'imgid': 6617,
#     'sentid': 33085},
#    {'tokens': ['here',
#      'is',
#      'a',
#      'rounded',
#      'triangle',
#      'lake',
#      'with',
#      'roads',
#      'trees',
#      'and',
#      'houses',
#      'built',
#      'along'],
#     'raw': 'here is a rounded triangle lake with roads trees and houses built along.',
#     'imgid': 6617,
#     'sentid': 33086},
#    {'tokens': ['here',
#      'is',
#      'a',
#      'rounded',
#      'triangle',
#      'lake',
#      'with',
#      'roads',
#      'trees',
#      'and',
#      'houses',
#      'built',
#      'along'],
#     'raw': 'here is a rounded triangle lake with roads trees and houses built along.',
#     'imgid': 6617,
#     'sentid': 33087},
#    {'tokens': ['rows',
#      'of',
#      'houses',
#      'and',
#      'roads',
#      'surrounds',
#      'this',
#      'green',
#      'triangular',
#      'pond'],
#     'raw': 'rows of houses and roads surrounds this green triangular pond .',
#     'imgid': 6617,
#     'sentid': 33088},
#    {'tokens': ['an',
#      'almost',
#      'triangular',
#      'green',
#      'pond',
#      'is',
#      'surrounded',
#      'by',
#      'many',
#      'green',
#      'trees',
#      'and',
#      'some',
#      'gray',
#      'buildings'],
#     'raw': 'an almost triangular green pond is surrounded by many green trees and some gray buildings .',
#     'imgid': 6617,
#     'sentid': 33089}],
#   'split': 'val',
#   'sentids': [33085, 33086, 33087, 33088, 33089],
#   'old_dataset_name': 'dataset_rsicd_modified',
#   'current_set_name': 'train'},
#  'rsicd_denseresidential_31.jpg': {'filename': 'denseresidential_31.jpg',
#   'imgid': 2734,
#   'sentences': [{'tokens': ['many',
#      'buildings',
#      'and',
#      'green',
#      'trees',
#      'are',
#      'in',
#      'a',
#      'dense',
#      'residential',
#      'area'],
#     'raw': 'many buildings and green trees are in a dense residential area .',
#     'imgid': 2734,
#     'sentid': 13670},
#    {'tokens': ['many',
#      'buildings',
#      'and',
#      'green',
#      'trees',
#      'are',
#      'in',
#      'a',
#      'dense',
#      'residential',
#      'area'],
#     'raw': 'many buildings and green trees are in a dense residential area .',
#     'imgid': 2734,
#     'sentid': 13671},
#    {'tokens': ['many',
#      'buildings',
#      'and',
#      'green',
#      'trees',
#      'are',
#      'in',
#      'a',
#      'dense',
#      'residential',
#      'area'],
#     'raw': 'many buildings and green trees are in a dense residential area .',
#     'imgid': 2734,
#     'sentid': 13672},
#    {'tokens': ['many',
#      'buildings',
#      'and',
#      'green',
#      'trees',
#      'are',
#      'in',
#      'a',
#      'dense',
#      'residential',
#      'area'],
#     'raw': 'many buildings and green trees are in a dense residential area .',
#     'imgid': 2734,
#     'sentid': 13673},
#    {'tokens': ['many',
#      'buildings',
#      'and',
#      'green',
#      'trees',
#      'are',
#      'in',
#      'a',
#      'dense',
#      'residential',
#      'area'],
#     'raw': 'many buildings and green trees are in a dense residential area .',
#     'imgid': 2734,
#     'sentid': 13674}],
#   'split': 'train',
#   'sentids': [13670, 13671, 13672, 13673, 13674],
#   'old_dataset_name': 'dataset_rsicd_modified',
#   'current_set_name': 'train'},
#  'rsicd_00072.jpg': {'filename': '00072.jpg',
#   'imgid': 10071,
#   'sentences': [{'tokens': ['a',
#      'football',
#      'field',
#      'is',
#      'wreathed',
#      'by',
#      'dense',
#      'woods',
#      'and',
#      'houses',
#      'decorated',
#      'with',
#      'red',
#      'roofs'],
#     'raw': 'a football field is wreathed by dense woods and houses decorated with red roofs .',
#     'imgid': 10071,
#     'sentid': 50355},
#    {'tokens': ['a',
#      'football',
#      'field',
#      'and',
#      'many',
#      'red',
#      'house',
#      'and',
#      'green',
#      'trees',
#      'beside'],
#     'raw': 'a football field and many red house and green trees beside .',
#     'imgid': 10071,
#     'sentid': 50356},
#    {'tokens': ['a',
#      'piece',
#      'of',
#      'red',
#      'buildings',
#      'with',
#      'green',
#      'plants',
#      'is',
#      'next',
#      'to',
#      'a',
#      'playground',
#      'with',
#      'two',
#      'basketball',
#      'fields',
#      'next',
#      'to',
#      'it'],
#     'raw': 'a piece of red buildings with green plants is next to a playground with two basketball fields next to it .',
#     'imgid': 10071,
#     'sentid': 50357},
#    {'tokens': ['a',
#      'playground',
#      'semi',
#      'surrounded',
#      'by',
#      'many',
#      'buildings',
#      'is',
#      'next',
#      'to',
#      'many',
#      'red',
#      'long',
#      'buildings',
#      'and',
#      'green',
#      'trees'],
#     'raw': 'a playground semi surrounded by many buildings is next to many red long buildings and green trees.',
#     'imgid': 10071,
#     'sentid': 50358},
#    {'tokens': ['a',
#      'large',
#      'playground',
#      'with',
#      'two',
#      'basketball',
#      'fields',
#      'next',
#      'to',
#      'it',
#      'is',
#      'semi-surrounded',
#      'by',
#      'red',
#      'houses'],
#     'raw': 'a large playground with two basketball fields next to it is semi-surrounded by red houses .',
#     'imgid': 10071,
#     'sentid': 50359}],
#   'split': 'train',
#   'sentids': [50355, 50356, 50357, 50358, 50359],
#   'old_dataset_name': 'dataset_rsicd_modified',
#   'current_set_name': 'train'},
#  'rsicd_industrial_202.jpg': {'filename': 'industrial_202.jpg',
#   'imgid': 3945,
#   'sentences': [{'tokens': ['many',
#      'buildings',
#      'and',
#      'green',
#      'trees',
#      'are',
#      'in',
#      'an',
#      'industrial',
#      'area'],
#     'raw': 'many buildings and green trees are in an industrial area .',
#     'imgid': 3945,
#     'sentid': 19725},
#    {'tokens': ['many',
#      'buildings',
#      'and',
#      'green',
#      'trees',
#      'are',
#      'in',
#      'an',
#      'industrial',
#      'area'],
#     'raw': 'many buildings and green trees are in an industrial area .',
#     'imgid': 3945,
#     'sentid': 19726},
#    {'tokens': ['many',
#      'buildings',
#      'and',
#      'green',
#      'trees',
#      'are',
#      'in',
#      'an',
#      'industrial',
#      'area'],
#     'raw': 'many buildings and green trees are in an industrial area .',
#     'imgid': 3945,
#     'sentid': 19727},
#    {'tokens': ['many',
#      'buildings',
#      'and',
#      'green',
#      'trees',
#      'are',
#      'in',
#      'an',
#      'industrial',
#      'area'],
#     'raw': 'many buildings and green trees are in an industrial area .',
#     'imgid': 3945,
#     'sentid': 19728},
#    {'tokens': ['many',
#      'buildings',
#      'and',
#      'green',
#      'trees',
#      'are',
#      'in',
#      'an',
#      'industrial',
#      'area'],
#     'raw': 'many buildings and green trees are in an industrial area .',
#     'imgid': 3945,
#     'sentid': 19729}],
#   'split': 'train',
#   'sentids': [19725, 19726, 19727, 19728, 19729],
#   'old_dataset_name': 'dataset_rsicd_modified',
#   'current_set_name': 'train'},
#  'rsicd_bareland_43.jpg': {'filename': 'bareland_43.jpg',
#   'imgid': 608,
#   'sentences': [{'tokens': ['the',
#      'grey',
#      'green',
#      'land',
#      'has',
#      'many',
#      'gullies'],
#     'raw': 'the grey green land has many gullies .',
#     'imgid': 608,
#     'sentid': 3040},
#    {'tokens': ['there',
#      'are',
#      'green',
#      'stripes',
#      'in',
#      'the',
#      'yellow',
#      'ground'],
#     'raw': 'there are green stripes in the yellow ground .',
#     'imgid': 608,
#     'sentid': 3041},
#    {'tokens': ['there',
#      'are',
#      'green',
#      'stripes',
#      'in',
#      'the',
#      'yellow',
#      'ground'],
#     'raw': 'there are green stripes in the yellow ground .',
#     'imgid': 608,
#     'sentid': 3042},
#    {'tokens': ['this',
#      'bare',
#      'land',
#      'is',
#      'messily',
#      'striped',
#      'with',
#      'ruttings'],
#     'raw': 'this bare land is messily striped with ruttings.',
#     'imgid': 608,
#     'sentid': 3043},
#    {'tokens': ['it',
#      'is',
#      'a',
#      'piece',
#      'of',
#      'gray',
#      'green',
#      'bare',
#      'land'],
#     'raw': 'it is a piece of gray green bare land.',
#     'imgid': 608,
#     'sentid': 3044}],
#   'split': 'val',
#   'sentids': [3040, 3041, 3042, 3043, 3044],
#   'old_dataset_name': 'dataset_rsicd_modified',
#   'current_set_name': 'train'},
#  'ucm_1798.jpg': {'filename': '1798.tif',
#   'imgid': 1797,
#   'sentences': [{'tokens': ['It',
#      'is',
#      'a',
#      'straight',
#      'runway',
#      'with',
#      'some',
#      'mark',
#      'lines',
#      'on',
#      'it'],
#     'raw': 'It is a straight runway with some mark lines on it .',
#     'imgid': 1797,
#     'sentid': 8985},
#    {'tokens': ['A',
#      'straight',
#      'runway',
#      'with',
#      'some',
#      'mark',
#      'lines',
#      'on',
#      'it'],
#     'raw': 'A straight runway with some mark lines on it .',
#     'imgid': 1797,
#     'sentid': 8986},
#    {'tokens': ['There',
#      'are',
#      'some',
#      'mark',
#      'lines',
#      'on',
#      'the',
#      'straight',
#      'runway'],
#     'raw': 'There are some mark lines on the straight runway .',
#     'imgid': 1797,
#     'sentid': 8987},
#    {'tokens': ['It',
#      'is',
#      'a',
#      'straight',
#      'runway',
#      'with',
#      'some',
#      'white',
#      'mark',
#      'lines',
#      'on',
#      'it'],
#     'raw': 'It is a straight runway with some white mark lines on it .',
#     'imgid': 1797,
#     'sentid': 8988},
#    {'tokens': ['A',
#      'straight',
#      'runway',
#      'with',
#      'some',
#      'white',
#      'mark',
#      'lines',
#      'on',
#      'it'],
#     'raw': 'A straight runway with some white mark lines on it .',
#     'imgid': 1797,
#     'sentid': 8989}],
#   'split': 'test',
#   'sentids': [8985, 8986, 8987, 8988, 8989],
#   'old_dataset_name': 'dataset_ucm_modified',
#   'current_set_name': 'train'},
#  'rsicd_denseresidential_43.jpg': {'filename': 'denseresidential_43.jpg',
#   'imgid': 2848,
#   'sentences': [{'tokens': ['on',
#      'both',
#      'sides',
#      'of',
#      'the',
#      'road',
#      'are',
#      'rows',
#      'of',
#      'densely',
#      'populated',
#      'areas'],
#     'raw': 'on both sides of the road are rows of densely populated areas .',
#     'imgid': 2848,
#     'sentid': 14240},
#    {'tokens': ['a',
#      'row',
#      'of',
#      'trees',
#      'were',
#      'planted',
#      'around',
#      'the',
#      'neighborhood'],
#     'raw': 'a row of trees were planted around the neighborhood .',
#     'imgid': 2848,
#     'sentid': 14241},
#    {'tokens': ['a',
#      'row',
#      'of',
#      'trees',
#      'were',
#      'planted',
#      'around',
#      'the',
#      'neighborhood'],
#     'raw': 'a row of trees were planted around the neighborhood .',
#     'imgid': 2848,
#     'sentid': 14242},
#    {'tokens': ['on',
#      'both',
#      'sides',
#      'of',
#      'the',
#      'road',
#      'are',
#      'rows',
#      'of',
#      'densely',
#      'populated',
#      'areas'],
#     'raw': 'on both sides of the road are rows of densely populated areas .',
#     'imgid': 2848,
#     'sentid': 14243},
#    {'tokens': ['on',
#      'both',
#      'sides',
#      'of',
#      'the',
#      'road',
#      'are',
#      'rows',
#      'of',
#      'densely',
#      'populated',
#      'areas'],
#     'raw': 'on both sides of the road are rows of densely populated areas .',
#     'imgid': 2848,
#     'sentid': 14244}],
#   'split': 'val',
#   'sentids': [14240, 14241, 14242, 14243, 14244],
#   'old_dataset_name': 'dataset_rsicd_modified',
#   'current_set_name': 'train'},
#  'rsicd_mediumresidential_83.jpg': {'filename': 'mediumresidential_83.jpg',
#   'imgid': 4772,
#   'sentences': [{'tokens': ['many',
#      'green',
#      'trees',
#      'and',
#      'some',
#      'buildings',
#      'are',
#      'in',
#      'a',
#      'medium',
#      'residential',
#      'area'],
#     'raw': 'many green trees and some buildings are in a medium residential area .',
#     'imgid': 4772,
#     'sentid': 23860},
#    {'tokens': ['many',
#      'green',
#      'trees',
#      'and',
#      'some',
#      'buildings',
#      'are',
#      'in',
#      'a',
#      'medium',
#      'residential',
#      'area'],
#     'raw': 'many green trees and some buildings are in a medium residential area .',
#     'imgid': 4772,
#     'sentid': 23861},
#    {'tokens': ['many',
#      'green',
#      'trees',
#      'and',
#      'some',
#      'buildings',
#      'are',
#      'in',
#      'a',
#      'medium',
#      'residential',
#      'area'],
#     'raw': 'many green trees and some buildings are in a medium residential area .',
#     'imgid': 4772,
#     'sentid': 23862},
#    {'tokens': ['many',
#      'green',
#      'trees',
#      'and',
#      'some',
#      'buildings',
#      'are',
#      'in',
#      'a',
#      'medium',
#      'residential',
#      'area'],
#     'raw': 'many green trees and some buildings are in a medium residential area .',
#     'imgid': 4772,
#     'sentid': 23863},
#    {'tokens': ['many',
#      'green',
#      'trees',
#      'and',
#      'some',
#      'buildings',
#      'are',
#      'in',
#      'a',
#      'medium',
#      'residential',
#      'area'],
#     'raw': 'many green trees and some buildings are in a medium residential area .',
#     'imgid': 4772,
#     'sentid': 23864}],
#   'split': 'test',
#   'sentids': [23860, 23861, 23862, 23863, 23864],
#   'old_dataset_name': 'dataset_rsicd_modified',
#   'current_set_name': 'train'},
#  'rsicd_stadium_168.jpg': {'filename': 'stadium_168.jpg',
#   'imgid': 9006,
#   'sentences': [{'tokens': ['some',
#      'buildings',
#      'and',
#      'a',
#      'parking',
#      'lot',
#      'are',
#      'near',
#      'a',
#      'large',
#      'stadium'],
#     'raw': 'some buildings and a parking lot are near a large stadium .',
#     'imgid': 9006,
#     'sentid': 45030},
#    {'tokens': ['some',
#      'buildings',
#      'and',
#      'a',
#      'parking',
#      'lot',
#      'are',
#      'near',
#      'a',
#      'large',
#      'stadium'],
#     'raw': 'some buildings and a parking lot are near a large stadium .',
#     'imgid': 9006,
#     'sentid': 45031},
#    {'tokens': ['some',
#      'buildings',
#      'and',
#      'a',
#      'parking',
#      'lot',
#      'are',
#      'near',
#      'a',
#      'large',
#      'stadium'],
#     'raw': 'some buildings and a parking lot are near a large stadium .',
#     'imgid': 9006,
#     'sentid': 45032},
#    {'tokens': ['some',
#      'buildings',
#      'and',
#      'a',
#      'parking',
#      'lot',
#      'are',
#      'near',
#      'a',
#      'large',
#      'stadium'],
#     'raw': 'some buildings and a parking lot are near a large stadium .',
#     'imgid': 9006,
#     'sentid': 45033},
#    {'tokens': ['some',
#      'buildings',
#      'and',
#      'a',
#      'parking',
#      'lot',
#      'are',
#      'near',
#      'a',
#      'large',
#      'stadium'],
#     'raw': 'some buildings and a parking lot are near a large stadium .',
#     'imgid': 9006,
#     'sentid': 45034}],
#   'split': 'train',
#   'sentids': [45030, 45031, 45032, 45033, 45034],
#   'old_dataset_name': 'dataset_rsicd_modified',
#   'current_set_name': 'train'},
#  'rsicd_00602.jpg': {'filename': '00602.jpg',
#   'imgid': 10601,
#   'sentences': [{'tokens': ['a',
#      'half-old',
#      'football',
#      'field',
#      'is',
#      'next',
#      'to',
#      'the',
#      'community',
#      'nearby'],
#     'raw': 'a half-old football field is next to the community nearby .',
#     'imgid': 10601,
#     'sentid': 53005},
#    {'tokens': ['a',
#      'playground',
#      'near',
#      'several',
#      'green',
#      'trees',
#      'is',
#      'surrounded',
#      'by',
#      'many',
#      'buildings'],
#     'raw': 'a playground near several green trees is surrounded by many buildings .',
#     'imgid': 10601,
#     'sentid': 53006},
#    {'tokens': ['a',
#      'playground',
#      'is',
#      'surrounded',
#      'by',
#      'many',
#      'buildings',
#      'and',
#      'several',
#      'green',
#      'trees'],
#     'raw': 'a playground is surrounded by many buildings and several green trees .',
#     'imgid': 10601,
#     'sentid': 53007},
#    {'tokens': ['a',
#      'playground',
#      'is',
#      'surrounded',
#      'by',
#      'several',
#      'green',
#      'trees',
#      'and',
#      'many',
#      'buildings'],
#     'raw': 'a playground is surrounded by several green trees and many buildings .',
#     'imgid': 10601,
#     'sentid': 53008},
#    {'tokens': ['a',
#      'playground',
#      'is',
#      'surrounded',
#      'by',
#      'many',
#      'buildings',
#      'and',
#      'several',
#      'green',
#      'trees'],
#     'raw': 'a playground is surrounded by many buildings and several green trees .',
#     'imgid': 10601,
#     'sentid': 53009}],
#   'split': 'train',
#   'sentids': [53005, 53006, 53007, 53008, 53009],
#   'old_dataset_name': 'dataset_rsicd_modified',
#   'current_set_name': 'train'},
#  'rsicd_bareland_220.jpg': {'filename': 'bareland_220.jpg',
#   'imgid': 495,
#   'sentences': [{'tokens': ['many',
#      'signs',
#      'are',
#      'in',
#      'a',
#      'piece',
#      'of',
#      'khaki',
#      'bare',
#      'land'],
#     'raw': 'many signs are in a piece of khaki bare land.',
#     'imgid': 495,
#     'sentid': 2475},
#    {'tokens': ['many',
#      'signs',
#      'are',
#      'in',
#      'a',
#      'piece',
#      'of',
#      'khaki',
#      'bare',
#      'land'],
#     'raw': 'many signs are in a piece of khaki bare land.',
#     'imgid': 495,
#     'sentid': 2476},
#    {'tokens': ['many',
#      'signs',
#      'are',
#      'in',
#      'a',
#      'piece',
#      'of',
#      'khaki',
#      'bare',
#      'land'],
#     'raw': 'many signs are in a piece of khaki bare land.',
#     'imgid': 495,
#     'sentid': 2477},
#    {'tokens': ['many',
#      'signs',
#      'are',
#      'in',
#      'a',
#      'piece',
#      'of',
#      'khaki',
#      'bare',
#      'land'],
#     'raw': 'many signs are in a piece of khaki bare land.',
#     'imgid': 495,
#     'sentid': 2478},
#    {'tokens': ['many',
#      'signs',
#      'are',
#      'in',
#      'a',
#      'piece',
#      'of',
#      'khaki',
#      'bare',
#      'land'],
#     'raw': 'many signs are in a piece of khaki bare land.',
#     'imgid': 495,
#     'sentid': 2479}],
#   'split': 'train',
#   'sentids': [2475, 2476, 2477, 2478, 2479],
#   'old_dataset_name': 'dataset_rsicd_modified',
#   'current_set_name': 'train'},
#  'rsicd_center_146.jpg': {'filename': 'center_146.jpg',
#   'imgid': 1702,
#   'sentences': [{'tokens': ['a',
#      'white',
#      'building',
#      'is',
#      'between',
#      'a',
#      'ferris',
#      'wheel',
#      'and',
#      'a',
#      'square',
#      'building',
#      'near',
#      'a',
#      'river',
#      'with',
#      'two',
#      'boats'],
#     'raw': 'a white building is between a ferris wheel and a square building near a river with two boats .',
#     'imgid': 1702,
#     'sentid': 8510},
#    {'tokens': ['a',
#      'white',
#      'building',
#      'is',
#      'between',
#      'a',
#      'ferris',
#      'wheel',
#      'and',
#      'a',
#      'square',
#      'building',
#      'near',
#      'a',
#      'river',
#      'with',
#      'two',
#      'boats'],
#     'raw': 'a white building is between a ferris wheel and a square building near a river with two boats .',
#     'imgid': 1702,
#     'sentid': 8511},
#    {'tokens': ['a',
#      'white',
#      'building',
#      'is',
#      'between',
#      'a',
#      'ferris',
#      'wheel',
#      'and',
#      'a',
#      'square',
#      'building',
#      'near',
#      'a',
#      'river',
#      'with',
#      'two',
#      'boats'],
#     'raw': 'a white building is between a ferris wheel and a square building near a river with two boats .',
#     'imgid': 1702,
#     'sentid': 8512},
#    {'tokens': ['a',
#      'white',
#      'building',
#      'is',
#      'between',
#      'a',
#      'ferris',
#      'wheel',
#      'and',
#      'a',
#      'square',
#      'building',
#      'near',
#      'a',
#      'river',
#      'with',
#      'two',
#      'boats'],
#     'raw': 'a white building is between a ferris wheel and a square building near a river with two boats .',
#     'imgid': 1702,
#     'sentid': 8513},
#    {'tokens': ['a',
#      'white',
#      'building',
#      'is',
#      'between',
#      'a',
#      'ferris',
#      'wheel',
#      'and',
#      'a',
#      'square',
#      'building',
#      'near',
#      'a',
#      'river',
#      'with',
#      'two',
#      'boats'],
#     'raw': 'a white building is between a ferris wheel and a square building near a river with two boats .',
#     'imgid': 1702,
#     'sentid': 8514}],
#   'split': 'train',
#   'sentids': [8510, 8511, 8512, 8513, 8514],
#   'old_dataset_name': 'dataset_rsicd_modified',
#   'current_set_name': 'train'},
#  'rsicd_mountain_251.jpg': {'filename': 'mountain_251.jpg',
#   'imgid': 4959,
#   'sentences': [{'tokens': ['it',
#      'is',
#      'a',
#      'piece',
#      'of',
#      'yellow',
#      'mountains'],
#     'raw': 'it is a piece of yellow mountains .',
#     'imgid': 4959,
#     'sentid': 24795},
#    {'tokens': ['it', 'is', 'a', 'piece', 'of', 'yellow', 'mountains'],
#     'raw': 'it is a piece of yellow mountains .',
#     'imgid': 4959,
#     'sentid': 24796},
#    {'tokens': ['it', 'is', 'a', 'piece', 'of', 'yellow', 'mountains'],
#     'raw': 'it is a piece of yellow mountains .',
#     'imgid': 4959,
#     'sentid': 24797},
#    {'tokens': ['it', 'is', 'a', 'piece', 'of', 'yellow', 'mountains'],
#     'raw': 'it is a piece of yellow mountains .',
#     'imgid': 4959,
#     'sentid': 24798},
#    {'tokens': ['it', 'is', 'a', 'piece', 'of', 'yellow', 'mountains'],
#     'raw': 'it is a piece of yellow mountains .',
#     'imgid': 4959,
#     'sentid': 24799}],
#   'split': 'train',
#   'sentids': [24795, 24796, 24797, 24798, 24799],
#   'old_dataset_name': 'dataset_rsicd_modified',
#   'current_set_name': 'train'},
#  'rsicd_church_130.jpg': {'filename': 'church_130.jpg',
#   'imgid': 1945,
#   'sentences': [{'tokens': ['some',
#      'buildings',
#      'and',
#      'green',
#      'trees',
#      'are',
#      'around',
#      'a',
#      'church'],
#     'raw': 'some buildings and green trees are around a church .',
#     'imgid': 1945,
#     'sentid': 9725},
#    {'tokens': ['some',
#      'buildings',
#      'and',
#      'green',
#      'trees',
#      'are',
#      'around',
#      'a',
#      'church'],
#     'raw': 'some buildings and green trees are around a church .',
#     'imgid': 1945,
#     'sentid': 9726},
#    {'tokens': ['some',
#      'buildings',
#      'and',
#      'green',
#      'trees',
#      'are',
#      'around',
#      'a',
#      'church'],
#     'raw': 'some buildings and green trees are around a church .',
#     'imgid': 1945,
#     'sentid': 9727},
#    {'tokens': ['some',
#      'buildings',
#      'and',
#      'green',
#      'trees',
#      'are',
#      'around',
#      'a',
#      'church'],
#     'raw': 'some buildings and green trees are around a church .',
#     'imgid': 1945,
#     'sentid': 9728},
#    {'tokens': ['some',
#      'buildings',
#      'and',
#      'green',
#      'trees',
#      'are',
#      'around',
#      'a',
#      'church'],
#     'raw': 'some buildings and green trees are around a church .',
#     'imgid': 1945,
#     'sentid': 9729}],
#   'split': 'train',
#   'sentids': [9725, 9726, 9727, 9728, 9729],
#   'old_dataset_name': 'dataset_rsicd_modified',
#   'current_set_name': 'train'},
#  'rsicd_square_259.jpg': {'filename': 'square_259.jpg',
#   'imgid': 8777,
#   'sentences': [{'tokens': ['many',
#      'buildings',
#      'and',
#      'green',
#      'trees',
#      'are',
#      'around',
#      'a',
#      'church',
#      'with',
#      'a',
#      'square',
#      'in',
#      'front',
#      'of',
#      'it'],
#     'raw': 'many buildings and green trees are around a church with a square in front of it .',
#     'imgid': 8777,
#     'sentid': 43885},
#    {'tokens': ['many',
#      'buildings',
#      'and',
#      'green',
#      'trees',
#      'are',
#      'around',
#      'a',
#      'church',
#      'with',
#      'a',
#      'square',
#      'in',
#      'front',
#      'of',
#      'it'],
#     'raw': 'many buildings and green trees are around a church with a square in front of it .',
#     'imgid': 8777,
#     'sentid': 43886},
#    {'tokens': ['many',
#      'buildings',
#      'and',
#      'green',
#      'trees',
#      'are',
#      'around',
#      'a',
#      'church',
#      'with',
#      'a',
#      'square',
#      'in',
#      'front',
#      'of',
#      'it'],
#     'raw': 'many buildings and green trees are around a church with a square in front of it .',
#     'imgid': 8777,
#     'sentid': 43887},
#    {'tokens': ['many',
#      'buildings',
#      'and',
#      'green',
#      'trees',
#      'are',
#      'around',
#      'a',
#      'church',
#      'with',
#      'a',
#      'square',
#      'in',
#      'front',
#      'of',
#      'it'],
#     'raw': 'many buildings and green trees are around a church with a square in front of it .',
#     'imgid': 8777,
#     'sentid': 43888},
#    {'tokens': ['many',
#      'buildings',
#      'and',
#      'green',
#      'trees',
#      'are',
#      'around',
#      'a',
#      'church',
#      'with',
#      'a',
#      'square',
#      'in',
#      'front',
#      'of',
#      'it'],
#     'raw': 'many buildings and green trees are around a church with a square in front of it .',
#     'imgid': 8777,
#     'sentid': 43889}],
#   'split': 'train',
#   'sentids': [43885, 43886, 43887, 43888, 43889],
#   'old_dataset_name': 'dataset_rsicd_modified',
#   'current_set_name': 'train'},
#  'rsicd_mediumresidential_114.jpg': {'filename': 'mediumresidential_114.jpg',
#   'imgid': 4517,
#   'sentences': [{'tokens': ['some',
#      'buildings',
#      'and',
#      'green',
#      'trees',
#      'are',
#      'in',
#      'a',
#      'medium',
#      'residential',
#      'area'],
#     'raw': 'some buildings and green trees are in a medium residential area .',
#     'imgid': 4517,
#     'sentid': 22585},
#    {'tokens': ['some',
#      'buildings',
#      'and',
#      'green',
#      'trees',
#      'are',
#      'in',
#      'a',
#      'medium',
#      'residential',
#      'area'],
#     'raw': 'some buildings and green trees are in a medium residential area .',
#     'imgid': 4517,
#     'sentid': 22586},
#    {'tokens': ['some',
#      'buildings',
#      'and',
#      'green',
#      'trees',
#      'are',
#      'in',
#      'a',
#      'medium',
#      'residential',
#      'area'],
#     'raw': 'some buildings and green trees are in a medium residential area .',
#     'imgid': 4517,
#     'sentid': 22587},
#    {'tokens': ['some',
#      'buildings',
#      'and',
#      'green',
#      'trees',
#      'are',
#      'in',
#      'a',
#      'medium',
#      'residential',
#      'area'],
#     'raw': 'some buildings and green trees are in a medium residential area .',
#     'imgid': 4517,
#     'sentid': 22588},
#    {'tokens': ['some',
#      'buildings',
#      'and',
#      'green',
#      'trees',
#      'are',
#      'in',
#      'a',
#      'medium',
#      'residential',
#      'area'],
#     'raw': 'some buildings and green trees are in a medium residential area .',
#     'imgid': 4517,
#     'sentid': 22589}],
#   'split': 'train',
#   'sentids': [22585, 22586, 22587, 22588, 22589],
#   'old_dataset_name': 'dataset_rsicd_modified',
#   'current_set_name': 'train'},
#  'rsicd_bareland_116.jpg': {'filename': 'bareland_116.jpg',
#   'imgid': 379,
#   'sentences': [{'tokens': ['it',
#      'is',
#      'a',
#      'large',
#      'piece',
#      'of',
#      'bare',
#      'land'],
#     'raw': 'it is a large piece of bare land.',
#     'imgid': 379,
#     'sentid': 1895},
#    {'tokens': ['it', 'is', 'a', 'large', 'piece', 'of', 'bare', 'land'],
#     'raw': 'it is a large piece of bare land.',
#     'imgid': 379,
#     'sentid': 1896},
#    {'tokens': ['it', 'is', 'a', 'large', 'piece', 'of', 'bare', 'land'],
#     'raw': 'it is a large piece of bare land.',
#     'imgid': 379,
#     'sentid': 1897},
#    {'tokens': ['it', 'is', 'a', 'large', 'piece', 'of', 'bare', 'land'],
#     'raw': 'it is a large piece of bare land.',
#     'imgid': 379,
#     'sentid': 1898},
#    {'tokens': ['it', 'is', 'a', 'large', 'piece', 'of', 'bare', 'land'],
#     'raw': 'it is a large piece of bare land.',
#     'imgid': 379,
#     'sentid': 1899}],
#   'split': 'train',
#   'sentids': [1895, 1896, 1897, 1898, 1899],
#   'old_dataset_name': 'dataset_rsicd_modified',
#   'current_set_name': 'train'},
#  'rsicd_desert_32.jpg': {'filename': 'desert_32.jpg',
#   'imgid': 3136,
#   'sentences': [{'tokens': ['there',
#      'is',
#      'no',
#      'plant',
#      'in',
#      'the',
#      'desert'],
#     'raw': 'there is no plant in the desert .',
#     'imgid': 3136,
#     'sentid': 15680},
#    {'tokens': ["there's",
#      'only',
#      'a',
#      'little',
#      'sand',
#      'in',
#      'the',
#      'desert'],
#     'raw': "there's only a little sand in the desert .",
#     'imgid': 3136,
#     'sentid': 15681},
#    {'tokens': ["there's",
#      'only',
#      'a',
#      'little',
#      'sand',
#      'in',
#      'the',
#      'desert'],
#     'raw': "there's only a little sand in the desert .",
#     'imgid': 3136,
#     'sentid': 15682},
#    {'tokens': ['there', 'is', 'no', 'plant', 'in', 'the', 'desert'],
#     'raw': 'there is no plant in the desert .',
#     'imgid': 3136,
#     'sentid': 15683},
#    {'tokens': ['there', 'is', 'no', 'plant', 'in', 'the', 'desert'],
#     'raw': 'there is no plant in the desert .',
#     'imgid': 3136,
#     'sentid': 15684}],
#   'split': 'train',
#   'sentids': [15680, 15681, 15682, 15683, 15684],
#   'old_dataset_name': 'dataset_rsicd_modified',
#   'current_set_name': 'train'},
#  'rsicd_desert_229.jpg': {'filename': 'desert_229.jpg',
#   'imgid': 3054,
#   'sentences': [{'tokens': ['some',
#      'small',
#      'spots',
#      'are',
#      'in',
#      'one',
#      'side',
#      'of',
#      'a',
#      'piece',
#      'of',
#      'gray',
#      'desert'],
#     'raw': 'some small spots are in one side of a piece of gray desert .',
#     'imgid': 3054,
#     'sentid': 15270},
#    {'tokens': ['some',
#      'small',
#      'spots',
#      'are',
#      'in',
#      'one',
#      'side',
#      'of',
#      'a',
#      'piece',
#      'of',
#      'gray',
#      'desert'],
#     'raw': 'some small spots are in one side of a piece of gray desert .',
#     'imgid': 3054,
#     'sentid': 15271},
#    {'tokens': ['some',
#      'small',
#      'spots',
#      'are',
#      'in',
#      'one',
#      'side',
#      'of',
#      'a',
#      'piece',
#      'of',
#      'gray',
#      'desert'],
#     'raw': 'some small spots are in one side of a piece of gray desert .',
#     'imgid': 3054,
#     'sentid': 15272},
#    {'tokens': ['some',
#      'small',
#      'spots',
#      'are',
#      'in',
#      'one',
#      'side',
#      'of',
#      'a',
#      'piece',
#      'of',
#      'gray',
#      'desert'],
#     'raw': 'some small spots are in one side of a piece of gray desert .',
#     'imgid': 3054,
#     'sentid': 15273},
#    {'tokens': ['some',
#      'small',
#      'spots',
#      'are',
#      'in',
#      'one',
#      'side',
#      'of',
#      'a',
#      'piece',
#      'of',
#      'gray',
#      'desert'],
#     'raw': 'some small spots are in one side of a piece of gray desert .',
#     'imgid': 3054,
#     'sentid': 15274}],
#   'split': 'train',
#   'sentids': [15270, 15271, 15272, 15273, 15274],
#   'old_dataset_name': 'dataset_rsicd_modified',
#   'current_set_name': 'train'},
#  'rsicd_port_298.jpg': {'filename': 'port_298.jpg',
#   'imgid': 6880,
#   'sentences': [{'tokens': ['some',
#      'boats',
#      'are',
#      'in',
#      'a',
#      'line',
#      'in',
#      'a',
#      'port',
#      'near',
#      'a',
#      'building'],
#     'raw': 'some boats are in a line in a port near a building .',
#     'imgid': 6880,
#     'sentid': 34400},
#    {'tokens': ['some',
#      'boats',
#      'are',
#      'in',
#      'a',
#      'line',
#      'in',
#      'a',
#      'port',
#      'near',
#      'a',
#      'building'],
#     'raw': 'some boats are in a line in a port near a building .',
#     'imgid': 6880,
#     'sentid': 34401},
#    {'tokens': ['some',
#      'boats',
#      'are',
#      'in',
#      'a',
#      'line',
#      'in',
#      'a',
#      'port',
#      'near',
#      'a',
#      'building'],
#     'raw': 'some boats are in a line in a port near a building .',
#     'imgid': 6880,
#     'sentid': 34402},
#    {'tokens': ['some',
#      'boats',
#      'are',
#      'in',
#      'a',
#      'line',
#      'in',
#      'a',
#      'port',
#      'near',
#      'a',
#      'building'],
#     'raw': 'some boats are in a line in a port near a building .',
#     'imgid': 6880,
#     'sentid': 34403},
#    {'tokens': ['some',
#      'boats',
#      'are',
#      'in',
#      'a',
#      'line',
#      'in',
#      'a',
#      'port',
#      'near',
#      'a',
#      'building'],
#     'raw': 'some boats are in a line in a port near a building .',
#     'imgid': 6880,
#     'sentid': 34404}],
#   'split': 'train',
#   'sentids': [34400, 34401, 34402, 34403, 34404],
#   'old_dataset_name': 'dataset_rsicd_modified',
#   'current_set_name': 'train'},
#  'rsicd_mediumresidential_255.jpg': {'filename': 'mediumresidential_255.jpg',
#   'imgid': 4673,
#   'sentences': [{'tokens': ['some',
#      'buildings',
#      'and',
#      'green',
#      'trees',
#      'are',
#      'in',
#      'a',
#      'medium',
#      'residential',
#      'area'],
#     'raw': 'some buildings and green trees are in a medium residential area .',
#     'imgid': 4673,
#     'sentid': 23365},
#    {'tokens': ['some',
#      'buildings',
#      'and',
#      'green',
#      'trees',
#      'are',
#      'in',
#      'a',
#      'medium',
#      'residential',
#      'area'],
#     'raw': 'some buildings and green trees are in a medium residential area .',
#     'imgid': 4673,
#     'sentid': 23366},
#    {'tokens': ['some',
#      'buildings',
#      'and',
#      'green',
#      'trees',
#      'are',
#      'in',
#      'a',
#      'medium',
#      'residential',
#      'area'],
#     'raw': 'some buildings and green trees are in a medium residential area .',
#     'imgid': 4673,
#     'sentid': 23367},
#    {'tokens': ['some',
#      'buildings',
#      'and',
#      'green',
#      'trees',
#      'are',
#      'in',
#      'a',
#      'medium',
#      'residential',
#      'area'],
#     'raw': 'some buildings and green trees are in a medium residential area .',
#     'imgid': 4673,
#     'sentid': 23368},
#    {'tokens': ['some',
#      'buildings',
#      'and',
#      'green',
#      'trees',
#      'are',
#      'in',
#      'a',
#      'medium',
#      'residential',
#      'area'],
#     'raw': 'some buildings and green trees are in a medium residential area .',
#     'imgid': 4673,
#     'sentid': 23369}],
#   'split': 'train',
#   'sentids': [23365, 23366, 23367, 23368, 23369],
#   'old_dataset_name': 'dataset_rsicd_modified',
#   'current_set_name': 'train'},
#  'ucm_950.jpg': {'filename': '950.tif',
#   'imgid': 949,
#   'sentences': [{'tokens': ['This',
#      'is',
#      'a',
#      'part',
#      'of',
#      'a',
#      'golf',
#      'course',
#      'with',
#      'green',
#      'turfs',
#      'and',
#      'some',
#      'bunkers',
#      'and',
#      'trees'],
#     'raw': 'This is a part of a golf course with green turfs and some bunkers and trees .',
#     'imgid': 949,
#     'sentid': 4745},
#    {'tokens': ['A',
#      'part',
#      'of',
#      'a',
#      'golf',
#      'course',
#      'with',
#      'some',
#      'bunkers',
#      'and',
#      'trees',
#      'while',
#      'a',
#      'trail',
#      'goes',
#      'through',
#      'the',
#      'turfs'],
#     'raw': 'A part of a golf course with some bunkers and trees while a trail goes through the turfs .',
#     'imgid': 949,
#     'sentid': 4746},
#    {'tokens': ['A',
#      'part',
#      'of',
#      'a',
#      'golf',
#      'course',
#      'with',
#      'a',
#      'trail',
#      'goes',
#      'through',
#      'the',
#      'turfs',
#      'and',
#      'some',
#      'bunkers',
#      'and',
#      'trees'],
#     'raw': 'A part of a golf coursea with a trail goes through the turfs and some bunkers and trees .',
#     'imgid': 949,
#     'sentid': 4747},
#    {'tokens': ['Some',
#      'bunkers',
#      'and',
#      'trees',
#      'with',
#      'a',
#      'trail',
#      'goes',
#      'through',
#      'the',
#      'turfs',
#      'in',
#      'the',
#      'golf',
#      'course'],
#     'raw': 'Some bunkers and trees with a trail goes through the turfs in the golf course .',
#     'imgid': 949,
#     'sentid': 4748},
#    {'tokens': ['Some',
#      'green',
#      'bunkers',
#      'and',
#      'trees',
#      'with',
#      'a',
#      'trail',
#      'goes',
#      'through',
#      'the',
#      'turfs',
#      'in',
#      'the',
#      'golf',
#      'course'],
#     'raw': 'Some green bunkers and trees with a trail goes through the turfs in the golf course .',
#     'imgid': 949,
#     'sentid': 4749}],
#   'split': 'train',
#   'sentids': [4745, 4746, 4747, 4748, 4749],
#   'old_dataset_name': 'dataset_ucm_modified',
#   'current_set_name': 'train'},
# ...
#      'trees',
#      'and',
#      'a',
#      'rectangular',
#      'lake'],
#     'raw': 'many buildings are around a park with many green trees and a rectangular lake .',
#     'imgid': 5147,
#     'sentid': 25739}],
#   'split': 'train',
#   'sentids': [25735, 25736, 25737, 25738, 25739],
#   'old_dataset_name': 'dataset_rsicd_modified',
#   'current_set_name': 'train'},
#  'rsicd_storagetanks_81.jpg': {'filename': 'storagetanks_81.jpg',
#   'imgid': 9560,
#   'sentences': [{'tokens': ['the',
#      'ground',
#      'has',
#      'three',
#      'spherical',
#      'storage',
#      'tank'],
#     'raw': 'the ground has three spherical storage tank .',
#     'imgid': 9560,
#     'sentid': 47800},
#    {'tokens': ['a', 'lot', 'of', 'grass', 'grew', 'on', 'the', 'ground'],
#     'raw': 'a lot of grass grew on the ground .',
#     'imgid': 9560,
#     'sentid': 47801},
#    {'tokens': ['three',
#      'storage',
#      'tanks',
#      'are',
#      'surrounded',
#      'by',
#      'green',
#      'meadow'],
#     'raw': 'three storage tanks are surrounded by green meadow .',
#     'imgid': 9560,
#     'sentid': 47802},
#    {'tokens': ['three',
#      'storage',
#      'tanks',
#      'are',
#      'surrounded',
#      'by',
#      'green',
#      'meadow'],
#     'raw': 'three storage tanks are surrounded by green meadow .',
#     'imgid': 9560,
#     'sentid': 47803},
#    {'tokens': ['the',
#      'ground',
#      'has',
#      'three',
#      'spherical',
#      'storage',
#      'tank'],
#     'raw': 'the ground has three spherical storage tank .',
#     'imgid': 9560,
#     'sentid': 47804}],
#   'split': 'test',
#   'sentids': [47800, 47801, 47802, 47803, 47804],
#   'old_dataset_name': 'dataset_rsicd_modified',
#   'current_set_name': 'train'},
#  'rsicd_mountain_67.jpg': {'filename': 'mountain_67.jpg',
#   'imgid': 5094,
#   'sentences': [{'tokens': ['roads',
#      'and',
#      'rivers',
#      'can',
#      'be',
#      'seen',
#      'in',
#      'the',
#      'valleys'],
#     'raw': 'roads and rivers can be seen in the valleys .',
#     'imgid': 5094,
#     'sentid': 25470},
#    {'tokens': ['roads',
#      'and',
#      'rivers',
#      'can',
#      'be',
#      'seen',
#      'in',
#      'the',
#      'valleys'],
#     'raw': 'roads and rivers can be seen in the valleys .',
#     'imgid': 5094,
#     'sentid': 25471},
#    {'tokens': ['roads',
#      'and',
#      'rivers',
#      'can',
#      'be',
#      'seen',
#      'in',
#      'the',
#      'valleys'],
#     'raw': 'roads and rivers can be seen in the valleys .',
#     'imgid': 5094,
#     'sentid': 25472},
#    {'tokens': ['it',
#      'is',
#      'a',
#      'beautiful',
#      'green',
#      'mountain',
#      'range',
#      'with',
#      'several',
#      'footpaths',
#      'traverses',
#      'through'],
#     'raw': 'it is a beautiful green mountain range with several footpaths traverses through .',
#     'imgid': 5094,
#     'sentid': 25473},
#    {'tokens': ['it',
#      'is',
#      'a',
#      'piece',
#      'of',
#      'irregular',
#      'green',
#      'mountains'],
#     'raw': 'it is a piece of irregular green mountains .',
#     'imgid': 5094,
#     'sentid': 25474}],
#   'split': 'val',
#   'sentids': [25470, 25471, 25472, 25473, 25474],
#   'old_dataset_name': 'dataset_rsicd_modified',
#   'current_set_name': 'train'},
#  'ucm_402.jpg': {'filename': '402.tif',
#   'imgid': 401,
#   'sentences': [{'tokens': ['There',
#      'are',
#      'lots',
#      'of',
#      'buildings',
#      'close',
#      'to',
#      'each',
#      'other'],
#     'raw': 'There are lots of buildings close to each other .',
#     'imgid': 401,
#     'sentid': 2005},
#    {'tokens': ['Many', 'buildings', 'close', 'to', 'each', 'other'],
#     'raw': 'Many buildings close to each other .',
#     'imgid': 401,
#     'sentid': 2006},
#    {'tokens': ['Many', 'buildings', 'with', 'white', 'and', 'red', 'roofs'],
#     'raw': 'Many buildings with white and red roofs .',
#     'imgid': 401,
#     'sentid': 2007},
#    {'tokens': ['Lots', 'of', 'buildings', 'close', 'to', 'each', 'other'],
#     'raw': 'Lots of buildings close to each other .',
#     'imgid': 401,
#     'sentid': 2008},
#    {'tokens': ['Just', 'buildings', 'here'],
#     'raw': 'Just buildings here .',
#     'imgid': 401,
#     'sentid': 2009}],
#   'split': 'train',
#   'sentids': [2005, 2006, 2007, 2008, 2009],
#   'old_dataset_name': 'dataset_ucm_modified',
#   'current_set_name': 'train'},
#  'rsicd_desert_81.jpg': {'filename': 'desert_81.jpg',
#   'imgid': 3190,
#   'sentences': [{'tokens': ['it',
#      'is',
#      'a',
#      'large',
#      'piece',
#      'of',
#      'yellow',
#      'desert'],
#     'raw': 'it is a large piece of yellow desert .',
#     'imgid': 3190,
#     'sentid': 15950},
#    {'tokens': ['it', 'is', 'a', 'large', 'piece', 'of', 'yellow', 'desert'],
#     'raw': 'it is a large piece of yellow desert .',
#     'imgid': 3190,
#     'sentid': 15951},
#    {'tokens': ['it', 'is', 'a', 'large', 'piece', 'of', 'yellow', 'desert'],
#     'raw': 'it is a large piece of yellow desert .',
#     'imgid': 3190,
#     'sentid': 15952},
#    {'tokens': ['it', 'is', 'a', 'large', 'piece', 'of', 'yellow', 'desert'],
#     'raw': 'it is a large piece of yellow desert .',
#     'imgid': 3190,
#     'sentid': 15953},
#    {'tokens': ['it', 'is', 'a', 'large', 'piece', 'of', 'yellow', 'desert'],
#     'raw': 'it is a large piece of yellow desert .',
#     'imgid': 3190,
#     'sentid': 15954}],
#   'split': 'test',
#   'sentids': [15950, 15951, 15952, 15953, 15954],
#   'old_dataset_name': 'dataset_rsicd_modified',
#   'current_set_name': 'train'},
#  'rsicd_port_87.jpg': {'filename': 'port_87.jpg',
#   'imgid': 7026,
#   'sentences': [{'tokens': ['some',
#      'boats',
#      'are',
#      'in',
#      'a',
#      'port',
#      'near',
#      'green',
#      'plants',
#      'and',
#      'many',
#      'buildings'],
#     'raw': 'some boats are in a port near green plants and many buildings .',
#     'imgid': 7026,
#     'sentid': 35130},
#    {'tokens': ['some',
#      'boats',
#      'are',
#      'in',
#      'a',
#      'port',
#      'near',
#      'green',
#      'plants',
#      'and',
#      'many',
#      'buildings'],
#     'raw': 'some boats are in a port near green plants and many buildings .',
#     'imgid': 7026,
#     'sentid': 35131},
#    {'tokens': ['some',
#      'boats',
#      'are',
#      'in',
#      'a',
#      'port',
#      'near',
#      'green',
#      'plants',
#      'and',
#      'many',
#      'buildings'],
#     'raw': 'some boats are in a port near green plants and many buildings .',
#     'imgid': 7026,
#     'sentid': 35132},
#    {'tokens': ['some',
#      'boats',
#      'are',
#      'in',
#      'a',
#      'port',
#      'near',
#      'green',
#      'plants',
#      'and',
#      'many',
#      'buildings'],
#     'raw': 'some boats are in a port near green plants and many buildings .',
#     'imgid': 7026,
#     'sentid': 35133},
#    {'tokens': ['some',
#      'boats',
#      'are',
#      'in',
#      'a',
#      'port',
#      'near',
#      'green',
#      'plants',
#      'and',
#      'many',
#      'buildings'],
#     'raw': 'some boats are in a port near green plants and many buildings .',
#     'imgid': 7026,
#     'sentid': 35134}],
#   'split': 'test',
#   'sentids': [35130, 35131, 35132, 35133, 35134],
#   'old_dataset_name': 'dataset_rsicd_modified',
#   'current_set_name': 'train'},
#  'rsicd_baseballfield_219.jpg': {'filename': 'baseballfield_219.jpg',
#   'imgid': 803,
#   'sentences': [{'tokens': ['the',
#      'baseball',
#      'field',
#      'field',
#      'is',
#      'surrounded',
#      'by',
#      'lush',
#      'trees',
#      'and',
#      'buildings'],
#     'raw': 'the baseball field field is surrounded by lush trees and buildings .',
#     'imgid': 803,
#     'sentid': 4015},
#    {'tokens': ['the',
#      'baseball',
#      'field',
#      'consists',
#      'of',
#      'a',
#      'large',
#      'lawn'],
#     'raw': 'the baseball field consists of a large lawn .',
#     'imgid': 803,
#     'sentid': 4016},
#    {'tokens': ['four',
#      'baseball',
#      'fields',
#      'in',
#      'different',
#      'sides',
#      'are',
#      'near',
#      'some',
#      'green',
#      'trees'],
#     'raw': 'four baseball fields in different sides are near some green trees .',
#     'imgid': 803,
#     'sentid': 4017},
#    {'tokens': ['four',
#      'baseball',
#      'fields',
#      'in',
#      'different',
#      'sides',
#      'are',
#      'near',
#      'some',
#      'green',
#      'trees'],
#     'raw': 'four baseball fields in different sides are near some green trees .',
#     'imgid': 803,
#     'sentid': 4018},
#    {'tokens': ['the',
#      'baseball',
#      'field',
#      'field',
#      'is',
#      'surrounded',
#      'by',
#      'lush',
#      'trees',
#      'and',
#      'buildings'],
#     'raw': 'the baseball field field is surrounded by lush trees and buildings .',
#     'imgid': 803,
#     'sentid': 4019}],
#   'split': 'train',
#   'sentids': [4015, 4016, 4017, 4018, 4019],
#   'old_dataset_name': 'dataset_rsicd_modified',
#   'current_set_name': 'train'},
#  'rsicd_bridge_267.jpg': {'filename': 'bridge_267.jpg',
#   'imgid': 1476,
#   'sentences': [{'tokens': ['several',
#      'cars',
#      'are',
#      'on',
#      'a',
#      'bridge',
#      'over',
#      'a',
#      'river',
#      'with',
#      'some',
#      'green',
#      'trees',
#      'in',
#      'two',
#      'sides'],
#     'raw': 'several cars are on a bridge over a river with some green trees in two sides',
#     'imgid': 1476,
#     'sentid': 7380},
#    {'tokens': ['several',
#      'cars',
#      'are',
#      'on',
#      'a',
#      'bridge',
#      'over',
#      'a',
#      'river',
#      'with',
#      'some',
#      'green',
#      'trees',
#      'in',
#      'two',
#      'sides'],
#     'raw': 'several cars are on a bridge over a river with some green trees in two sides',
#     'imgid': 1476,
#     'sentid': 7381},
#    {'tokens': ['several',
#      'cars',
#      'are',
#      'on',
#      'a',
#      'bridge',
#      'over',
#      'a',
#      'river',
#      'with',
#      'some',
#      'green',
#      'trees',
#      'in',
#      'two',
#      'sides'],
#     'raw': 'several cars are on a bridge over a river with some green trees in two sides',
#     'imgid': 1476,
#     'sentid': 7382},
#    {'tokens': ['several',
#      'cars',
#      'are',
#      'on',
#      'a',
#      'bridge',
#      'over',
#      'a',
#      'river',
#      'with',
#      'some',
#      'green',
#      'trees',
#      'in',
#      'two',
#      'sides'],
#     'raw': 'several cars are on a bridge over a river with some green trees in two sides',
#     'imgid': 1476,
#     'sentid': 7383},
#    {'tokens': ['several',
#      'cars',
#      'are',
#      'on',
#      'a',
#      'bridge',
#      'over',
#      'a',
#      'river',
#      'with',
#      'some',
#      'green',
#      'trees',
#      'in',
#      'two',
#      'sides'],
#     'raw': 'several cars are on a bridge over a river with some green trees in two sides',
#     'imgid': 1476,
#     'sentid': 7384}],
#   'split': 'train',
#   'sentids': [7380, 7381, 7382, 7383, 7384],
#   'old_dataset_name': 'dataset_rsicd_modified',
#   'current_set_name': 'train'},
#  'rsicd_pond_405.jpg': {'filename': 'pond_405.jpg',
#   'imgid': 6580,
#   'sentences': [{'tokens': ['the',
#      'pond',
#      'with',
#      'trees',
#      'in',
#      'it',
#      'is',
#      'next',
#      'to',
#      'a',
#      'piece',
#      'of',
#      'trees',
#      'and',
#      'a',
#      'tract',
#      'of',
#      'farmland'],
#     'raw': 'the pond with trees in it is next to a piece of trees and a tract of farmland .',
#     'imgid': 6580,
#     'sentid': 32900},
#    {'tokens': ['a',
#      'pentagonal',
#      'pond',
#      'is',
#      'lying',
#      'among',
#      'a',
#      'forest',
#      'and',
#      'red',
#      'field',
#      'which',
#      'is',
#      'surrounded',
#      'by',
#      'trees'],
#     'raw': 'a pentagonal pond is lying among a forest and red field which is surrounded by trees.',
#     'imgid': 6580,
#     'sentid': 32901},
#    {'tokens': ['a',
#      'pentagonal',
#      'pond',
#      'is',
#      'lying',
#      'among',
#      'a',
#      'forest',
#      'and',
#      'red',
#      'field',
#      'which',
#      'is',
#      'surrounded',
#      'by',
#      'trees'],
#     'raw': 'a pentagonal pond is lying among a forest and red field which is surrounded by trees.',
#     'imgid': 6580,
#     'sentid': 32902},
#    {'tokens': ['here',
#      'lies',
#      'a',
#      'pentagonal',
#      'pond',
#      'with',
#      'a',
#      'little',
#      'island',
#      'in',
#      'it',
#      'surrounded',
#      'by',
#      'woods',
#      'and',
#      'bare',
#      'land'],
#     'raw': 'here lies a pentagonal pond with a little island in it surrounded by woods and bare land .',
#     'imgid': 6580,
#     'sentid': 32903},
#    {'tokens': ['a',
#      'pentagon',
#      'green',
#      'pond',
#      'is',
#      'surrounded',
#      'by',
#      'many',
#      'green',
#      'trees',
#      'and',
#      'bare',
#      'lands'],
#     'raw': 'a pentagon green pond is surrounded by many green trees and bare lands.',
#     'imgid': 6580,
#     'sentid': 32904}],
#   'split': 'val',
#   'sentids': [32900, 32901, 32902, 32903, 32904],
#   'old_dataset_name': 'dataset_rsicd_modified',
#   'current_set_name': 'train'},
#  'ucm_867.jpg': {'filename': '867.tif',
#   'imgid': 866,
#   'sentences': [{'tokens': ['There',
#      'are',
#      'two',
#      'straight',
#      'freeways',
#      'with',
#      'some',
#      'plants',
#      'beside',
#      'them'],
#     'raw': 'There are two straight freeways with some plants beside them .',
#     'imgid': 866,
#     'sentid': 4330},
#    {'tokens': ['There',
#      'are',
#      'two',
#      'straight',
#      'freeways',
#      'with',
#      'some',
#      'cars',
#      'on',
#      'them'],
#     'raw': 'There are two straight freeways with some cars on them .',
#     'imgid': 866,
#     'sentid': 4331},
#    {'tokens': ['Two',
#      'straight',
#      'freeways',
#      'with',
#      'some',
#      'plants',
#      'beside',
#      'them'],
#     'raw': 'Two straight freeways with some plants beside them .',
#     'imgid': 866,
#     'sentid': 4332},
#    {'tokens': ['Two',
#      'straight',
#      'freeways',
#      'with',
#      'some',
#      'plants',
#      'beside',
#      'them',
#      'and',
#      'some',
#      'cars',
#      'on',
#      'the',
#      'roads'],
#     'raw': 'Two straight freeways with some plants beside them and some cars on the roads .',
#     'imgid': 866,
#     'sentid': 4333},
#    {'tokens': ['Two',
#      'straight',
#      'freeways',
#      'with',
#      'some',
#      'cars',
#      'on',
#      'them'],
#     'raw': 'Two straight freeways with some cars on them .',
#     'imgid': 866,
#     'sentid': 4334}],
#   'split': 'train',
#   'sentids': [4330, 4331, 4332, 4333, 4334],
#   'old_dataset_name': 'dataset_ucm_modified',
#   'current_set_name': 'train'},
#  'sydney_7.jpg': {'filename': '7.tif',
#   'imgid': 6,
#   'sentences': [{'tokens': ['Lots',
#      'of',
#      'houses',
#      'with',
#      'red',
#      'and',
#      'orange',
#      'roofs',
#      'arranged',
#      'neatly',
#      'and',
#      'a',
#      'crossroad',
#      'in',
#      'the',
#      'middle'],
#     'raw': 'Lots of houses with red and orange roofs arranged neatly and a crossroad in the middle .',
#     'imgid': 6,
#     'sentid': 30},
#    {'tokens': ['A',
#      'residential',
#      'area',
#      'with',
#      'houses',
#      'arranged',
#      'neatly',
#      'and',
#      'some',
#      'roads',
#      'go',
#      'through',
#      'this',
#      'area'],
#     'raw': 'A residential area with houses arranged neatly and some roads go through this area .',
#     'imgid': 6,
#     'sentid': 31},
#    {'tokens': ['A',
#      'town',
#      'with',
#      'many',
#      'houses',
#      'arranged',
#      'in',
#      'lines',
#      'while',
#      'a',
#      'crossroad',
#      'in',
#      'the',
#      'middle'],
#     'raw': 'A town with many houses arranged in lines while a crossroad in the middle .',
#     'imgid': 6,
#     'sentid': 32},
#    {'tokens': ['A',
#      'residential',
#      'area',
#      'with',
#      'houses',
#      'arranged',
#      'neatly',
#      'while',
#      'many',
#      'plants',
#      'on',
#      'the',
#      'roadside'],
#     'raw': 'A residential area with houses arranged neatly while many plants on the roadside .',
#     'imgid': 6,
#     'sentid': 33},
#    {'tokens': ['A',
#      'residential',
#      'area',
#      'with',
#      'houses',
#      'arranged',
#      'neatly',
#      'while',
#      'a',
#      'crossroad',
#      'in',
#      'the',
#      'middle'],
#     'raw': 'A residential area with houses arranged neatly while a crossroad in the middle .',
#     'imgid': 6,
#     'sentid': 34}],
#   'split': 'train',
#   'sentids': [30, 31, 32, 33, 34],
#   'old_dataset_name': 'dataset_sydney_modified',
#   'current_set_name': 'train'},
#  ...}
